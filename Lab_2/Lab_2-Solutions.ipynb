# %% [markdown]
# # Lab 2
#
# ## Introduction
# With this lab data grouping and graphing will be explored. There is always a great deal of information you can gather by grouping and comparing various columns within a dataframe. In addition for data summarization graphing is an important tool to have.
#
# HTTP data will be used for this exercise. The data was generated from various PCAPs that have been collected that contain both legitimate traffic as well as traffic relating to exploit kits. While no malicious traffic is contained within the log file there are malicious domains and URLS (it's recommened you don't visit them). While this traffic was generated by running Bro over a series of PCAPS, similar data can be obtained from various Web Proxies, this is a nice cross over example of what is possible with your own data.
#
# Some goals will be understand when the data was generated, what systems generated,high-level stats about the traffic, and the types of data transferred within the connections.
#
# ___

# %% [markdown]
# ## Exercises
#
# ### File Input
# Using what you learned in the last lab cread in the log (csv) file provided for you.
#
# #### Hints
# * The file name is in the current directory and is called *http.log*
# * There is no header to the file
# * It's *[TAB]* seperated
# * The fields are: 'ts', 'uid', 'id.orig_h', 'id.orig_p', 'id.resp_h', 'id.resp_p', 'trans_depth', 'method', 'host', 'uri', 'referrer', 'user_agent', 'request_body_len', 'response_body_len', 'status_code', 'status_msg', 'info_code', 'info_msg', 'filename', 'tags', 'username', 'password', 'proxied', 'orig_fuids', 'orig_mime_types', 'resp_fuids', 'resp_mime_types', 'sample'

# %%
import pandas as pd
http_df = pd.read_csv("./http.log", header=None, sep="\t", names=['ts', 'uid', 'id.orig_h', 'id.orig_p', 'id.resp_h', 'id.resp_p', 'trans_depth', 'method', 'host', 'uri', 'referrer', 'user_agent', 'request_body_len', 'response_body_len', 'status_code', 'status_msg', 'info_code', 'info_msg', 'filename', 'tags', 'username', 'password', 'proxied', 'orig_fuids', 'orig_mime_types', 'resp_fuids', 'resp_mime_types', 'sample'])

# %% [markdown]
# ### Clean-up the timestamp
# Now that you've got the data imported, cleanup up the timestamp column *ts*. Don't forget to re-assign back to the *ts* column.

# %%
from datetime import datetime
http_df['ts'] = [datetime.fromtimestamp(float(date)) for date in http_df['ts'].values]

# %% [markdown]
# In the next cell the timestamp column is set to be the new index of the dataframe. By default dataframes are indexed by the row number, and by indexing by timestamp it's easier to perform various types of time series analysis. After the assignment a quick **head()** is performed, and in the output you'll see that the *ts* has moved "down and to the left". The new location of the *ts* heading indicates that it is now the index, and has replaced the default.

# %%
http_df = http_df.set_index('ts')
http_df.head()
# Out:
#                                            uid      id.orig_h  id.orig_p  \
# ts
# 2012-05-30 19:09:27.177343  ChBJ7L2l1Vcl8PmMxh  192.168.88.10       1030
# 2012-05-30 19:09:28.343725  CKH7Eu1pUtdXF8KKq8  192.168.88.10       1031
# 2012-05-30 19:09:29.124170  CMjfL821GNMgnPFTa9  192.168.88.10       1034
# 2012-05-30 19:09:29.142869  Ckt4Bw4pZVSaU17gSg  192.168.88.10       1035
# 2012-05-30 19:09:29.602005  ChBJ7L2l1Vcl8PmMxh  192.168.88.10       1030
#
#                                  id.resp_h  id.resp_p  trans_depth method  \
# ts
# 2012-05-30 19:09:27.177343  188.121.46.128         80            1    GET
# 2012-05-30 19:09:28.343725    50.28.53.156         80            1    GET
# 2012-05-30 19:09:29.124170  188.72.248.160         80            1    GET
# 2012-05-30 19:09:29.142869    69.63.148.95         80            1    GET
# 2012-05-30 19:09:29.602005  188.121.46.128         80            2    GET
#
#                                                host  \
# ts
# 2012-05-30 19:09:27.177343               myfecm.com
# 2012-05-30 19:09:28.343725       www.daysofyorr.com
# 2012-05-30 19:09:29.124170            potialosce.tk
# 2012-05-30 19:09:29.142869  www.12secondcommute.com
# 2012-05-30 19:09:29.602005               myfecm.com
#
#                                                   uri            referrer  \
# ts
# 2012-05-30 19:09:27.177343                          /                   -
# 2012-05-30 19:09:28.343725                /release.js  http://myfecm.com/
# 2012-05-30 19:09:29.124170             /25433658.html  http://myfecm.com/
# 2012-05-30 19:09:29.142869  /common/formValidation.js  http://myfecm.com/
# 2012-05-30 19:09:29.602005            /button_bg6.jpg  http://myfecm.com/
#
#                                    ...         filename     tags  username  \
# ts                                 ...
# 2012-05-30 19:09:27.177343         ...                -  (empty)         -
# 2012-05-30 19:09:28.343725         ...                -  (empty)         -
# 2012-05-30 19:09:29.124170         ...                -  (empty)         -
# 2012-05-30 19:09:29.142869         ...                -  (empty)         -
# 2012-05-30 19:09:29.602005         ...                -  (empty)         -
#
#                            password proxied orig_fuids orig_mime_types  \
# ts
# 2012-05-30 19:09:27.177343        -       -          -               -
# 2012-05-30 19:09:28.343725        -       -          -               -
# 2012-05-30 19:09:29.124170        -       -          -               -
# 2012-05-30 19:09:29.142869        -       -          -               -
# 2012-05-30 19:09:29.602005        -       -          -               -
#
#                                     resp_fuids resp_mime_types sample
# ts
# 2012-05-30 19:09:27.177343   FmrItE3tE6uWAdmZV       text/html    NaN
# 2012-05-30 19:09:28.343725  FyKJaS1eo05A7BfpRj      text/plain    NaN
# 2012-05-30 19:09:29.124170  FzLBH53sLcK6bEiRai       text/html    NaN
# 2012-05-30 19:09:29.142869  F6UaIl1po975GOkGJh      text/plain    NaN
# 2012-05-30 19:09:29.602005  FjxdXz2z8deZMyEdvb      image/jpeg    NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Selecting Based on Index Values
#
# With the default indexing in dataframes you can select elements or slices of elements based on numbers (similarly to how lists work in Python). With a time indexed dataframe various parts of dates, or whole dates, can be used to select rows.
#
# A year can be used eg: 2012, a year and month '2012-02' or a year, month and day '2012-02-20'.

# %%
http_df['2012-02-20':'2012-02-23'].head()
# Out:
#                                            uid     id.orig_h  id.orig_p  \
# ts
# 2012-02-21 14:41:14.255273  CtWsBc4G3XZhz8ISrf  192.168.4.10       1030
# 2012-02-21 14:41:14.453622  CccAGN3T84z7dlY3bd  192.168.4.10       1031
# 2012-02-21 14:41:14.532165  CccAGN3T84z7dlY3bd  192.168.4.10       1031
# 2012-02-21 14:41:14.694098  CccAGN3T84z7dlY3bd  192.168.4.10       1031
# 2012-02-21 14:41:14.777528  CccAGN3T84z7dlY3bd  192.168.4.10       1031
#
#                                 id.resp_h  id.resp_p  trans_depth method  \
# ts
# 2012-02-21 14:41:14.255273  173.245.61.14         80            1    GET
# 2012-02-21 14:41:14.453622  74.125.45.157         80            1    GET
# 2012-02-21 14:41:14.532165  74.125.45.157         80            2    GET
# 2012-02-21 14:41:14.694098  74.125.45.157         80            3    GET
# 2012-02-21 14:41:14.777528  74.125.45.157         80            4    GET
#
#                                                      host  \
# ts
# 2012-02-21 14:41:14.255273                    adotomi.net
# 2012-02-21 14:41:14.453622  pagead2.googlesyndication.com
# 2012-02-21 14:41:14.532165  pagead2.googlesyndication.com
# 2012-02-21 14:41:14.694098  pagead2.googlesyndication.com
# 2012-02-21 14:41:14.777528  pagead2.googlesyndication.com
#
#                                                                         uri  \
# ts
# 2012-02-21 14:41:14.255273                                                /
# 2012-02-21 14:41:14.453622                              /pagead/show_ads.js
# 2012-02-21 14:41:14.532165  /pagead/js/r20120208/r20110914/show_ads_impl.js
# 2012-02-21 14:41:14.694098                            /pagead/render_ads.js
# 2012-02-21 14:41:14.777528                                   /pagead/osd.js
#
#                                        referrer         ...          filename  \
# ts                                                      ...
# 2012-02-21 14:41:14.255273                    -         ...                 -
# 2012-02-21 14:41:14.453622  http://adotomi.net/         ...                 -
# 2012-02-21 14:41:14.532165  http://adotomi.net/         ...                 -
# 2012-02-21 14:41:14.694098  http://adotomi.net/         ...                 -
# 2012-02-21 14:41:14.777528  http://adotomi.net/         ...                 -
#
#                                tags  username password proxied orig_fuids  \
# ts
# 2012-02-21 14:41:14.255273  (empty)         -        -       -          -
# 2012-02-21 14:41:14.453622  (empty)         -        -       -          -
# 2012-02-21 14:41:14.532165  (empty)         -        -       -          -
# 2012-02-21 14:41:14.694098  (empty)         -        -       -          -
# 2012-02-21 14:41:14.777528  (empty)         -        -       -          -
#
#                            orig_mime_types          resp_fuids  \
# ts
# 2012-02-21 14:41:14.255273               -   FJO3B8unjL3z3WgN4
# 2012-02-21 14:41:14.453622               -   FPUAcdaUKTOhxP5Cc
# 2012-02-21 14:41:14.532165               -  FAW1ua1cI03wuK24D5
# 2012-02-21 14:41:14.694098               -  Fzqd0y13zQ5dIt0S7f
# 2012-02-21 14:41:14.777528               -  FjdqXt25dn4xiBnS91
#
#                            resp_mime_types sample
# ts
# 2012-02-21 14:41:14.255273       text/html    NaN
# 2012-02-21 14:41:14.453622      text/plain    NaN
# 2012-02-21 14:41:14.532165      text/plain    NaN
# 2012-02-21 14:41:14.694098      text/plain    NaN
# 2012-02-21 14:41:14.777528      text/plain    NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Time Resampling
# Time indexed information can be resampled and summarized.
#
# Below is a resampling on day *D* that will count up the number of occurences per day. Try various date selections to get a feel for how the sampling works and how it can be used to summarize data.

# %%
http_df['2012-02-20':'2012-02-23'].resample("D", how='count').head()
# Out:
#              uid  id.orig_h  id.orig_p  id.resp_h  id.resp_p  trans_depth  \
# ts
# 2012-02-20  1581       1581       1581       1581       1581         1581
# 2012-02-21   589        589        589        589        589          589
# 2012-02-22  2509       2509       2509       2509       2509         2509
# 2012-02-23   339        339        339        339        339          339
#
#             method  host   uri  referrer    ...     filename  tags  username  \
# ts                                          ...
# 2012-02-20    1581  1581  1581      1581    ...         1581  1581      1581
# 2012-02-21     589   589   589       589    ...          589   589       589
# 2012-02-22    2509  2509  2509      2509    ...         2509  2509      2509
# 2012-02-23     339   339   339       339    ...          339   339       339
#
#             password  proxied  orig_fuids  orig_mime_types  resp_fuids  \
# ts
# 2012-02-20      1581     1581        1581             1581        1581
# 2012-02-21       589      589         589              589         589
# 2012-02-22      2509     2509        2509             2509        2509
# 2012-02-23       339      339         339              339         339
#
#             resp_mime_types  sample
# ts
# 2012-02-20             1581       0
# 2012-02-21              589       0
# 2012-02-22             2509       0
# 2012-02-23              339       0
#
# [4 rows x 27 columns]

# %% [markdown]
# Try the resample example from above with some of the other options for resample. Replace the *D* with some other values to get different frequencies.
#
# | Alias | Description
# | ------| -----------
# | B | business day frequency
# | C | custom business day frequency (experimental)
# | D | calendar day frequency
# | W | weekly frequency
# | M | month end frequency
# | BM | business month end frequency
# | CBM | custom business month end frequency
# | MS | month start frequency
# | BMS | business month start frequency
# | CBMS | custom business month start frequency
# | Q | quarter end frequency
# | BQ | business quarter endfrequency
# | QS | quarter start frequency
# | BQS | business quarter start frequency
# | A | year end frequency
# | BA | business year end frequency
# | ASyear | start frequency
# | BAS | business year start frequency
# | H | hourly frequency
# | T | minutely frequency
# | S | secondly frequency
# | L | milliseonds
# | U | microseconds

# %%
http_df[].resample("D", how='count').head()
# Out:
#   File "<ipython-input-7-e2ad67a01157>", line 1
#     http_df[].resample("D", how='count').head()
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Graphing Time Series Data
# After getting a grasp on the various ways to look at time indexed data, it's useful to display it visually. With this section the same progression as above will be used.
#
# The cell below will generate a time series graph of both the request and response bodies, summed up over their timestamps.

# %%
import matplotlib.pyplot as plt
pylab.rcParams['figure.figsize'] = (16.0, 5.0)

df = http_df[['request_body_len','response_body_len']]
df.plot();

# %% [markdown]
# A small copy of the HTTP dataframe **http_df** is stored in **df** it only contains 2 columns *[request_body_len, response_body_len]*, this enables the comparision of the request and response body lengths.
#
# Below is another way to graph the resampled data. In this case the data is resampled on *month*, and when no **how** parameter is passed to **resample()** it defaults to *mean*.
#
# #### Hint
# If you're going to use anything but *'count'* as the paremember to **how**, you need to make sure it's numeric data.

# %%
resamp = df.resample("M")
resamp.plot(style='g--')

# %% [markdown]
# ### Graphing Multiple Views (Time Series)
# It's possible to graph muliple **how** methods as well. This can help identify different patterns in the data.

# %%
resamp = df.resample("M", how=['mean', 'count', 'sum'])
resamp.plot(subplots=True)
resamp.plot()

# %% [markdown]
# Above, the response_body_len sum really sticks out in the bottom graph, but viwing the smaller graphs above it's possible to see that it's not because of an increase in the number of requests (it's simply because more information was received, in aggregate, over all the connections).
#
# ___
#
# Below, the *count* column was added for you, try doing the same type graph as above and incorporate **np.min** and **np.max** into your resampling.
#
# #### Hint
# Do not put sigle quotes around **np.min** or **np.max**.

# %%
df['count'] = 1
df = df['count'].cumsum()
resamp = df.resample("M", how=['mean', np.min, np.max])
resamp.plot(subplots=True)
resamp.plot()

# %% [markdown]
# ### Dataframe Grouping
# Another useful way to look at data is how different groups of values look with one another. For this pandas offeres the **groupby()** command. It allows you to specify an arbitray list of columns in your dataframe that are evaluated left-to-right in terms of grouping.
#
# The example below shows how *resp_mime_type* (filetype returned by the server) breaks down, and then per-filetype what *user_agents* requested those files. You can see the number of entries per-column per-value in the table.

# %%
http_df.groupby(['resp_mime_types','user_agent']).count()
# Out:
#                                                                                                                                                                           uid  \
# resp_mime_types user_agent
# -               (empty)                                                                                                                                                   169
#                 -                                                                                                                                                         582
#                 ????1                                                                                                                                                       1
#                 AYAgent.aye                                                                                                                                                 1
#                 B2BFB2BDDEC2B5B7C7B1C1A786819A9D94A8C4C5C7CBC4DEC5C7C2DEAE8FC2C6C0C4|0|AK-81                                                                                7
#                 DefaultPack                                                                                                                                                14
#                 Dv4                                                                                                                                                         2
#                 Google page                                                                                                                                                 1
#                 Googlebot/2.1 (+http://www.google.com/bot.html)                                                                                                             2
#                 IE                                                                                                                                                         61
#                 IE 9.0                                                                                                                                                      1
#                 IE7.0                                                                                                                                                      22
#                 Internet Explorer                                                                                                                                          25
#                 Java/1.6.0_10                                                                                                                                              30
#                 MSIE 9.0                                                                                                                                                    1
#                 Microsoft BITS/6.6                                                                                                                                          4
#                 Microsoft Internet Explorer/1.0 (Windows 95)                                                                                                                1
#                 Microsoft-CryptoAPI/5.131.2600.2180                                                                                                                         4
#                 Microsoft-WebDAV-MiniRedir/5.1.2600                                                                                                                       118
#                 Mozilla/1.22 (compatible; MSIE 10.0; Windows 3.1)                                                                                                           3
#                 Mozilla/3.0 (compatible; Indy Library)                                                                                                                     18
#                 Mozilla/4.0                                                                                                                                               262
#                 Mozilla/4.0 (Windows XP 5.1) Java/1.6.0_10                                                                                                               1624
#                 Mozilla/4.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.2.10) Gecko/2009801003 Firefox/3.4.0                                                                 1
#                 Mozilla/4.0 (compatible. MSIE 8.0. Windows NT 5.1)                                                                                                          1
#                 Mozilla/4.0 (compatible; 2600.xpsp_sp2_rtm.040803-2158; uid=1b88000074050000a7538350; MSIE 6.0.2900.2180;)                                                  1
#                 Mozilla/4.0 (compatible; MSIE 10.0; Windows NT 6.2; Trident/4.0                                                                                             1
#                 Mozilla/4.0 (compatible; MSIE 2.0; Windows NT 5.0; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0)    24
#                 Mozilla/4.0 (compatible; MSIE 4.01; Windows NT 5.0)                                                                                                         1
#                 Mozilla/4.0 (compatible; MSIE 5.01; Windows NT 5.0)                                                                                                         4
# ...                                                                                                                                                                       ...
# text/x-c        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                   998
#                 Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 6.0)                                                                                                          2
#                 Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Trident/4.0)                                                                                             6
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                           296
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                         3
#                 Mozilla/5.0 (Windows NT 6.1; WOW64; rv:17.0) Gecko/20100101 Firefox/17.0 AlexaToolbar/alxf-2.17                                                             1
#                 Mozilla/5.0 (Windows NT 6.3; Trident/7.0; Touch; rv:11.0) like Gecko                                                                                        1
#                 Mozilla/5.0 (Windows; U; Windows NT 6.0; en-GB; rv:1.9.2.26) Gecko/20120128 Firefox/3.6.26 ( .NET CLR 3.5.30729; .NET4.0C) ;ShopperReports                  1
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)                                                                                            2
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)                                                                                     1
# text/x-c++      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                    24
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                             4
# text/x-pascal   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                    23
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                             9
# text/x-php      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                     7
# video/mp2p      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                     2
# video/mp4       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                    45
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                            34
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                         1
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)                                                                                     1
# video/x-flv     Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                   170
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                           116
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                         1
# video/x-ms-asf  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                     1
#                 NSPlayer/9.0.0.3250                                                                                                                                         3
#                 NSPlayer/9.0.0.3250 WMFSDK/9.0                                                                                                                              2
#                 Windows-Media-Player/9.00.00.3250                                                                                                                           1
# video/x-msvideo Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                     2
#                 Windows-Media-Player/9.00.00.3250                                                                                                                           2
#                 contype                                                                                                                                                     1
#
#                                                                                                                                                                          id.orig_h  \
# resp_mime_types user_agent
# -               (empty)                                                                                                                                                        169
#                 -                                                                                                                                                              582
#                 ????1                                                                                                                                                            1
#                 AYAgent.aye                                                                                                                                                      1
#                 B2BFB2BDDEC2B5B7C7B1C1A786819A9D94A8C4C5C7CBC4DEC5C7C2DEAE8FC2C6C0C4|0|AK-81                                                                                     7
#                 DefaultPack                                                                                                                                                     14
#                 Dv4                                                                                                                                                              2
#                 Google page                                                                                                                                                      1
#                 Googlebot/2.1 (+http://www.google.com/bot.html)                                                                                                                  2
#                 IE                                                                                                                                                              61
#                 IE 9.0                                                                                                                                                           1
#                 IE7.0                                                                                                                                                           22
#                 Internet Explorer                                                                                                                                               25
#                 Java/1.6.0_10                                                                                                                                                   30
#                 MSIE 9.0                                                                                                                                                         1
#                 Microsoft BITS/6.6                                                                                                                                               4
#                 Microsoft Internet Explorer/1.0 (Windows 95)                                                                                                                     1
#                 Microsoft-CryptoAPI/5.131.2600.2180                                                                                                                              4
#                 Microsoft-WebDAV-MiniRedir/5.1.2600                                                                                                                            118
#                 Mozilla/1.22 (compatible; MSIE 10.0; Windows 3.1)                                                                                                                3
#                 Mozilla/3.0 (compatible; Indy Library)                                                                                                                          18
#                 Mozilla/4.0                                                                                                                                                    262
#                 Mozilla/4.0 (Windows XP 5.1) Java/1.6.0_10                                                                                                                    1624
#                 Mozilla/4.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.2.10) Gecko/2009801003 Firefox/3.4.0                                                                      1
#                 Mozilla/4.0 (compatible. MSIE 8.0. Windows NT 5.1)                                                                                                               1
#                 Mozilla/4.0 (compatible; 2600.xpsp_sp2_rtm.040803-2158; uid=1b88000074050000a7538350; MSIE 6.0.2900.2180;)                                                       1
#                 Mozilla/4.0 (compatible; MSIE 10.0; Windows NT 6.2; Trident/4.0                                                                                                  1
#                 Mozilla/4.0 (compatible; MSIE 2.0; Windows NT 5.0; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0)         24
#                 Mozilla/4.0 (compatible; MSIE 4.01; Windows NT 5.0)                                                                                                              1
#                 Mozilla/4.0 (compatible; MSIE 5.01; Windows NT 5.0)                                                                                                              4
# ...                                                                                                                                                                            ...
# text/x-c        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                        998
#                 Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 6.0)                                                                                                               2
#                 Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Trident/4.0)                                                                                                  6
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                296
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                              3
#                 Mozilla/5.0 (Windows NT 6.1; WOW64; rv:17.0) Gecko/20100101 Firefox/17.0 AlexaToolbar/alxf-2.17                                                                  1
#                 Mozilla/5.0 (Windows NT 6.3; Trident/7.0; Touch; rv:11.0) like Gecko                                                                                             1
#                 Mozilla/5.0 (Windows; U; Windows NT 6.0; en-GB; rv:1.9.2.26) Gecko/20120128 Firefox/3.6.26 ( .NET CLR 3.5.30729; .NET4.0C) ;ShopperReports                       1
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)                                                                                                 2
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)                                                                                          1
# text/x-c++      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                         24
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                  4
# text/x-pascal   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                         23
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                  9
# text/x-php      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          7
# video/mp2p      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          2
# video/mp4       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                         45
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                 34
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                              1
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)                                                                                          1
# video/x-flv     Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                        170
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                116
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                              1
# video/x-ms-asf  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          1
#                 NSPlayer/9.0.0.3250                                                                                                                                              3
#                 NSPlayer/9.0.0.3250 WMFSDK/9.0                                                                                                                                   2
#                 Windows-Media-Player/9.00.00.3250                                                                                                                                1
# video/x-msvideo Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          2
#                 Windows-Media-Player/9.00.00.3250                                                                                                                                2
#                 contype                                                                                                                                                          1
#
#                                                                                                                                                                          id.orig_p  \
# resp_mime_types user_agent
# -               (empty)                                                                                                                                                        169
#                 -                                                                                                                                                              582
#                 ????1                                                                                                                                                            1
#                 AYAgent.aye                                                                                                                                                      1
#                 B2BFB2BDDEC2B5B7C7B1C1A786819A9D94A8C4C5C7CBC4DEC5C7C2DEAE8FC2C6C0C4|0|AK-81                                                                                     7
#                 DefaultPack                                                                                                                                                     14
#                 Dv4                                                                                                                                                              2
#                 Google page                                                                                                                                                      1
#                 Googlebot/2.1 (+http://www.google.com/bot.html)                                                                                                                  2
#                 IE                                                                                                                                                              61
#                 IE 9.0                                                                                                                                                           1
#                 IE7.0                                                                                                                                                           22
#                 Internet Explorer                                                                                                                                               25
#                 Java/1.6.0_10                                                                                                                                                   30
#                 MSIE 9.0                                                                                                                                                         1
#                 Microsoft BITS/6.6                                                                                                                                               4
#                 Microsoft Internet Explorer/1.0 (Windows 95)                                                                                                                     1
#                 Microsoft-CryptoAPI/5.131.2600.2180                                                                                                                              4
#                 Microsoft-WebDAV-MiniRedir/5.1.2600                                                                                                                            118
#                 Mozilla/1.22 (compatible; MSIE 10.0; Windows 3.1)                                                                                                                3
#                 Mozilla/3.0 (compatible; Indy Library)                                                                                                                          18
#                 Mozilla/4.0                                                                                                                                                    262
#                 Mozilla/4.0 (Windows XP 5.1) Java/1.6.0_10                                                                                                                    1624
#                 Mozilla/4.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.2.10) Gecko/2009801003 Firefox/3.4.0                                                                      1
#                 Mozilla/4.0 (compatible. MSIE 8.0. Windows NT 5.1)                                                                                                               1
#                 Mozilla/4.0 (compatible; 2600.xpsp_sp2_rtm.040803-2158; uid=1b88000074050000a7538350; MSIE 6.0.2900.2180;)                                                       1
#                 Mozilla/4.0 (compatible; MSIE 10.0; Windows NT 6.2; Trident/4.0                                                                                                  1
#                 Mozilla/4.0 (compatible; MSIE 2.0; Windows NT 5.0; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0)         24
#                 Mozilla/4.0 (compatible; MSIE 4.01; Windows NT 5.0)                                                                                                              1
#                 Mozilla/4.0 (compatible; MSIE 5.01; Windows NT 5.0)                                                                                                              4
# ...                                                                                                                                                                            ...
# text/x-c        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                        998
#                 Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 6.0)                                                                                                               2
#                 Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Trident/4.0)                                                                                                  6
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                296
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                              3
#                 Mozilla/5.0 (Windows NT 6.1; WOW64; rv:17.0) Gecko/20100101 Firefox/17.0 AlexaToolbar/alxf-2.17                                                                  1
#                 Mozilla/5.0 (Windows NT 6.3; Trident/7.0; Touch; rv:11.0) like Gecko                                                                                             1
#                 Mozilla/5.0 (Windows; U; Windows NT 6.0; en-GB; rv:1.9.2.26) Gecko/20120128 Firefox/3.6.26 ( .NET CLR 3.5.30729; .NET4.0C) ;ShopperReports                       1
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)                                                                                                 2
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)                                                                                          1
# text/x-c++      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                         24
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                  4
# text/x-pascal   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                         23
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                  9
# text/x-php      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          7
# video/mp2p      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          2
# video/mp4       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                         45
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                 34
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                              1
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)                                                                                          1
# video/x-flv     Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                        170
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                116
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                              1
# video/x-ms-asf  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          1
#                 NSPlayer/9.0.0.3250                                                                                                                                              3
#                 NSPlayer/9.0.0.3250 WMFSDK/9.0                                                                                                                                   2
#                 Windows-Media-Player/9.00.00.3250                                                                                                                                1
# video/x-msvideo Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          2
#                 Windows-Media-Player/9.00.00.3250                                                                                                                                2
#                 contype                                                                                                                                                          1
#
#                                                                                                                                                                          id.resp_h  \
# resp_mime_types user_agent
# -               (empty)                                                                                                                                                        169
#                 -                                                                                                                                                              582
#                 ????1                                                                                                                                                            1
#                 AYAgent.aye                                                                                                                                                      1
#                 B2BFB2BDDEC2B5B7C7B1C1A786819A9D94A8C4C5C7CBC4DEC5C7C2DEAE8FC2C6C0C4|0|AK-81                                                                                     7
#                 DefaultPack                                                                                                                                                     14
#                 Dv4                                                                                                                                                              2
#                 Google page                                                                                                                                                      1
#                 Googlebot/2.1 (+http://www.google.com/bot.html)                                                                                                                  2
#                 IE                                                                                                                                                              61
#                 IE 9.0                                                                                                                                                           1
#                 IE7.0                                                                                                                                                           22
#                 Internet Explorer                                                                                                                                               25
#                 Java/1.6.0_10                                                                                                                                                   30
#                 MSIE 9.0                                                                                                                                                         1
#                 Microsoft BITS/6.6                                                                                                                                               4
#                 Microsoft Internet Explorer/1.0 (Windows 95)                                                                                                                     1
#                 Microsoft-CryptoAPI/5.131.2600.2180                                                                                                                              4
#                 Microsoft-WebDAV-MiniRedir/5.1.2600                                                                                                                            118
#                 Mozilla/1.22 (compatible; MSIE 10.0; Windows 3.1)                                                                                                                3
#                 Mozilla/3.0 (compatible; Indy Library)                                                                                                                          18
#                 Mozilla/4.0                                                                                                                                                    262
#                 Mozilla/4.0 (Windows XP 5.1) Java/1.6.0_10                                                                                                                    1624
#                 Mozilla/4.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.2.10) Gecko/2009801003 Firefox/3.4.0                                                                      1
#                 Mozilla/4.0 (compatible. MSIE 8.0. Windows NT 5.1)                                                                                                               1
#                 Mozilla/4.0 (compatible; 2600.xpsp_sp2_rtm.040803-2158; uid=1b88000074050000a7538350; MSIE 6.0.2900.2180;)                                                       1
#                 Mozilla/4.0 (compatible; MSIE 10.0; Windows NT 6.2; Trident/4.0                                                                                                  1
#                 Mozilla/4.0 (compatible; MSIE 2.0; Windows NT 5.0; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0)         24
#                 Mozilla/4.0 (compatible; MSIE 4.01; Windows NT 5.0)                                                                                                              1
#                 Mozilla/4.0 (compatible; MSIE 5.01; Windows NT 5.0)                                                                                                              4
# ...                                                                                                                                                                            ...
# text/x-c        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                        998
#                 Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 6.0)                                                                                                               2
#                 Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Trident/4.0)                                                                                                  6
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                296
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                              3
#                 Mozilla/5.0 (Windows NT 6.1; WOW64; rv:17.0) Gecko/20100101 Firefox/17.0 AlexaToolbar/alxf-2.17                                                                  1
#                 Mozilla/5.0 (Windows NT 6.3; Trident/7.0; Touch; rv:11.0) like Gecko                                                                                             1
#                 Mozilla/5.0 (Windows; U; Windows NT 6.0; en-GB; rv:1.9.2.26) Gecko/20120128 Firefox/3.6.26 ( .NET CLR 3.5.30729; .NET4.0C) ;ShopperReports                       1
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)                                                                                                 2
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)                                                                                          1
# text/x-c++      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                         24
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                  4
# text/x-pascal   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                         23
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                  9
# text/x-php      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          7
# video/mp2p      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          2
# video/mp4       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                         45
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                 34
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                              1
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)                                                                                          1
# video/x-flv     Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                        170
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                116
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                              1
# video/x-ms-asf  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          1
#                 NSPlayer/9.0.0.3250                                                                                                                                              3
#                 NSPlayer/9.0.0.3250 WMFSDK/9.0                                                                                                                                   2
#                 Windows-Media-Player/9.00.00.3250                                                                                                                                1
# video/x-msvideo Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          2
#                 Windows-Media-Player/9.00.00.3250                                                                                                                                2
#                 contype                                                                                                                                                          1
#
#                                                                                                                                                                          id.resp_p  \
# resp_mime_types user_agent
# -               (empty)                                                                                                                                                        169
#                 -                                                                                                                                                              582
#                 ????1                                                                                                                                                            1
#                 AYAgent.aye                                                                                                                                                      1
#                 B2BFB2BDDEC2B5B7C7B1C1A786819A9D94A8C4C5C7CBC4DEC5C7C2DEAE8FC2C6C0C4|0|AK-81                                                                                     7
#                 DefaultPack                                                                                                                                                     14
#                 Dv4                                                                                                                                                              2
#                 Google page                                                                                                                                                      1
#                 Googlebot/2.1 (+http://www.google.com/bot.html)                                                                                                                  2
#                 IE                                                                                                                                                              61
#                 IE 9.0                                                                                                                                                           1
# ...
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                               3
#                 Mozilla/5.0 (Windows NT 6.1; WOW64; rv:17.0) Gecko/20100101 Firefox/17.0 AlexaToolbar/alxf-2.17                                                                   1
#                 Mozilla/5.0 (Windows NT 6.3; Trident/7.0; Touch; rv:11.0) like Gecko                                                                                              1
#                 Mozilla/5.0 (Windows; U; Windows NT 6.0; en-GB; rv:1.9.2.26) Gecko/20120128 Firefox/3.6.26 ( .NET CLR 3.5.30729; .NET4.0C) ;ShopperReports                        1
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)                                                                                                  2
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)                                                                                           1
# text/x-c++      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          24
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                   4
# text/x-pascal   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          23
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                   9
# text/x-php      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                           7
# video/mp2p      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                           2
# video/mp4       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                          45
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                  34
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                               1
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)                                                                                           1
# video/x-flv     Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                         170
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                                 116
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                               1
# video/x-ms-asf  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                           1
#                 NSPlayer/9.0.0.3250                                                                                                                                               3
#                 NSPlayer/9.0.0.3250 WMFSDK/9.0                                                                                                                                    2
#                 Windows-Media-Player/9.00.00.3250                                                                                                                                 1
# video/x-msvideo Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                           2
#                 Windows-Media-Player/9.00.00.3250                                                                                                                                 2
#                 contype                                                                                                                                                           1
#
#                                                                                                                                                                          sample
# resp_mime_types user_agent
# -               (empty)                                                                                                                                                       0
#                 -                                                                                                                                                             0
#                 ????1                                                                                                                                                         0
#                 AYAgent.aye                                                                                                                                                   0
#                 B2BFB2BDDEC2B5B7C7B1C1A786819A9D94A8C4C5C7CBC4DEC5C7C2DEAE8FC2C6C0C4|0|AK-81                                                                                  0
#                 DefaultPack                                                                                                                                                   0
#                 Dv4                                                                                                                                                           0
#                 Google page                                                                                                                                                   0
#                 Googlebot/2.1 (+http://www.google.com/bot.html)                                                                                                               0
#                 IE                                                                                                                                                            0
#                 IE 9.0                                                                                                                                                        0
#                 IE7.0                                                                                                                                                         0
#                 Internet Explorer                                                                                                                                             0
#                 Java/1.6.0_10                                                                                                                                                 0
#                 MSIE 9.0                                                                                                                                                      0
#                 Microsoft BITS/6.6                                                                                                                                            0
#                 Microsoft Internet Explorer/1.0 (Windows 95)                                                                                                                  0
#                 Microsoft-CryptoAPI/5.131.2600.2180                                                                                                                           0
#                 Microsoft-WebDAV-MiniRedir/5.1.2600                                                                                                                           0
#                 Mozilla/1.22 (compatible; MSIE 10.0; Windows 3.1)                                                                                                             0
#                 Mozilla/3.0 (compatible; Indy Library)                                                                                                                        0
#                 Mozilla/4.0                                                                                                                                                   0
#                 Mozilla/4.0 (Windows XP 5.1) Java/1.6.0_10                                                                                                                    0
#                 Mozilla/4.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.2.10) Gecko/2009801003 Firefox/3.4.0                                                                   0
#                 Mozilla/4.0 (compatible. MSIE 8.0. Windows NT 5.1)                                                                                                            0
#                 Mozilla/4.0 (compatible; 2600.xpsp_sp2_rtm.040803-2158; uid=1b88000074050000a7538350; MSIE 6.0.2900.2180;)                                                    0
#                 Mozilla/4.0 (compatible; MSIE 10.0; Windows NT 6.2; Trident/4.0                                                                                               0
#                 Mozilla/4.0 (compatible; MSIE 2.0; Windows NT 5.0; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0)       0
#                 Mozilla/4.0 (compatible; MSIE 4.01; Windows NT 5.0)                                                                                                           0
#                 Mozilla/4.0 (compatible; MSIE 5.01; Windows NT 5.0)                                                                                                           0
# ...                                                                                                                                                                         ...
# text/x-c        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                       0
#                 Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 6.0)                                                                                                            0
#                 Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1; Trident/4.0)                                                                                               0
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                               0
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                           0
#                 Mozilla/5.0 (Windows NT 6.1; WOW64; rv:17.0) Gecko/20100101 Firefox/17.0 AlexaToolbar/alxf-2.17                                                               0
#                 Mozilla/5.0 (Windows NT 6.3; Trident/7.0; Touch; rv:11.0) like Gecko                                                                                          0
#                 Mozilla/5.0 (Windows; U; Windows NT 6.0; en-GB; rv:1.9.2.26) Gecko/20120128 Firefox/3.6.26 ( .NET CLR 3.5.30729; .NET4.0C) ;ShopperReports                    0
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; Trident/6.0)                                                                                              0
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)                                                                                       0
# text/x-c++      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                       0
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                               0
# text/x-pascal   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                       0
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                               0
# text/x-php      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                       0
# video/mp2p      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                       0
# video/mp4       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                       0
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                               0
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                           0
#                 Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.1; WOW64; Trident/6.0)                                                                                       0
# video/x-flv     Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                       0
#                 Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                                                                                               0
#                 Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.4 (KHTML, like Gecko) Chrome/22.0.1229.94 Safari/537.4                                                           0
# video/x-ms-asf  Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                       0
#                 NSPlayer/9.0.0.3250                                                                                                                                           0
#                 NSPlayer/9.0.0.3250 WMFSDK/9.0                                                                                                                                0
#                 Windows-Media-Player/9.00.00.3250                                                                                                                             0
# video/x-msvideo Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                                                                                                       0
#                 Windows-Media-Player/9.00.00.3250                                                                                                                             0
#                 contype                                                                                                                                                       0
#
# [1503 rows x 25 columns]

# %% [markdown]
# It's also possible to select rows (as learned in Lab 1) and then do a **groupby()** to look at various sub views of the data.
#
# This looks at all rows associated with those 2 different *user_agent*s, and then shows how many entries are in the data per-user-agent per-filetype.

# %%
http_df[http_df['user_agent'].isin(
    ['Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)',
     'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)'])].groupby(['resp_mime_types','user_agent']).count()
# Out:
#                                                                                                         uid  \
# resp_mime_types                      user_agent
# -                                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)          64458
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)  45411
# application/msword                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              1
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      1
# application/octet-stream             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)            775
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)    875
# application/pdf                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)           2768
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)    143
# application/vnd.ms-cab-compressed    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)             29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)     12
# application/vnd.ms-fontobject        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)           1008
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)   1151
# application/vnd.ms-opentype          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)             25
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)     23
# application/x-123                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)             52
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)     19
# application/x-bittorrent             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              4
# application/x-dosexec                Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)           5685
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)   2643
# application/x-dosexec,binary         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              2
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)     24
# application/x-dosexec,text/plain     Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      1
# application/x-elc                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)            496
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)     72
# application/x-font-ttf               Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)             29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)     16
# application/x-gzip                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)             14
# application/x-shockwave-flash        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)           7328
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)   2482
# application/x-shockwave-flash,binary Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              2
# ...                                                                                                     ...
# image/png                            Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)  19078
# image/svg+xml                        Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)     47
# image/tiff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              7
# image/x-icon                         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)             62
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)    432
# image/x-ms-bmp                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)             90
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)     45
# text/html                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)          94276
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)  46765
# text/plain                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)          89484
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)  56085
# text/plain,text/plain                Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      4
# text/troff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)            185
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)     49
# text/x-asm                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)            946
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)    239
# text/x-c                             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)            998
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)    296
# text/x-c++                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)             24
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      4
# text/x-pascal                        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)             23
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      9
# text/x-php                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              7
# video/mp2p                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              2
# video/mp4                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)             45
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)     34
# video/x-flv                          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)            170
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)    116
# video/x-ms-asf                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              1
# video/x-msvideo                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              2
#
#                                                                                                       id.orig_h  \
# resp_mime_types                      user_agent
# -                                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              64458
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      45411
# application/msword                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  1
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          1
# application/octet-stream             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                775
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        875
# application/pdf                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               2768
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        143
# application/vnd.ms-cab-compressed    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         12
# application/vnd.ms-fontobject        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               1008
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       1151
# application/vnd.ms-opentype          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 25
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         23
# application/x-123                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 52
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         19
# application/x-bittorrent             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  4
# application/x-dosexec                Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               5685
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       2643
# application/x-dosexec,binary         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         24
# application/x-dosexec,text/plain     Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          1
# application/x-elc                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                496
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         72
# application/x-font-ttf               Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         16
# application/x-gzip                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 14
# application/x-shockwave-flash        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               7328
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       2482
# application/x-shockwave-flash,binary Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
# ...                                                                                                         ...
# image/png                            Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      19078
# image/svg+xml                        Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         47
# image/tiff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  7
# image/x-icon                         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 62
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        432
# image/x-ms-bmp                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 90
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         45
# text/html                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              94276
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      46765
# text/plain                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              89484
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      56085
# text/plain,text/plain                Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          4
# text/troff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                185
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         49
# text/x-asm                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                946
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        239
# text/x-c                             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                998
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        296
# text/x-c++                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 24
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          4
# text/x-pascal                        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 23
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          9
# text/x-php                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  7
# video/mp2p                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
# video/mp4                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 45
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         34
# video/x-flv                          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                170
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        116
# video/x-ms-asf                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  1
# video/x-msvideo                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
#
#                                                                                                       id.orig_p  \
# resp_mime_types                      user_agent
# -                                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              64458
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      45411
# application/msword                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  1
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          1
# application/octet-stream             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                775
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        875
# application/pdf                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               2768
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        143
# application/vnd.ms-cab-compressed    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         12
# application/vnd.ms-fontobject        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               1008
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       1151
# application/vnd.ms-opentype          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 25
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         23
# application/x-123                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 52
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         19
# application/x-bittorrent             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  4
# application/x-dosexec                Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               5685
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       2643
# application/x-dosexec,binary         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         24
# application/x-dosexec,text/plain     Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          1
# application/x-elc                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                496
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         72
# application/x-font-ttf               Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         16
# application/x-gzip                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 14
# application/x-shockwave-flash        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               7328
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       2482
# application/x-shockwave-flash,binary Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
# ...                                                                                                         ...
# image/png                            Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      19078
# image/svg+xml                        Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         47
# image/tiff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  7
# image/x-icon                         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 62
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        432
# image/x-ms-bmp                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 90
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         45
# text/html                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              94276
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      46765
# text/plain                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              89484
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      56085
# text/plain,text/plain                Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          4
# text/troff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                185
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         49
# text/x-asm                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                946
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        239
# text/x-c                             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                998
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        296
# text/x-c++                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 24
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          4
# text/x-pascal                        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 23
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          9
# text/x-php                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  7
# video/mp2p                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
# video/mp4                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 45
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         34
# video/x-flv                          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                170
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        116
# video/x-ms-asf                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  1
# video/x-msvideo                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
#
#                                                                                                       id.resp_h  \
# resp_mime_types                      user_agent
# -                                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              64458
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      45411
# application/msword                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  1
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          1
# application/octet-stream             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                775
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        875
# application/pdf                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               2768
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        143
# application/vnd.ms-cab-compressed    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         12
# application/vnd.ms-fontobject        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               1008
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       1151
# application/vnd.ms-opentype          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 25
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         23
# application/x-123                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 52
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         19
# application/x-bittorrent             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  4
# application/x-dosexec                Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               5685
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       2643
# application/x-dosexec,binary         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         24
# application/x-dosexec,text/plain     Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          1
# application/x-elc                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                496
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         72
# application/x-font-ttf               Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         16
# application/x-gzip                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 14
# application/x-shockwave-flash        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               7328
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       2482
# application/x-shockwave-flash,binary Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
# ...                                                                                                         ...
# image/png                            Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      19078
# image/svg+xml                        Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         47
# image/tiff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  7
# image/x-icon                         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 62
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        432
# image/x-ms-bmp                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 90
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         45
# text/html                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              94276
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      46765
# text/plain                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              89484
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      56085
# text/plain,text/plain                Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          4
# text/troff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                185
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         49
# text/x-asm                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                946
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        239
# text/x-c                             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                998
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        296
# text/x-c++                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 24
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          4
# text/x-pascal                        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 23
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          9
# text/x-php                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  7
# video/mp2p                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
# video/mp4                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 45
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         34
# video/x-flv                          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                170
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        116
# video/x-ms-asf                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  1
# video/x-msvideo                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
#
#                                                                                                       id.resp_p  \
# resp_mime_types                      user_agent
# -                                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              64458
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      45411
# application/msword                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  1
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          1
# application/octet-stream             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                775
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        875
# application/pdf                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               2768
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        143
# application/vnd.ms-cab-compressed    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         12
# application/vnd.ms-fontobject        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               1008
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       1151
# application/vnd.ms-opentype          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 25
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         23
# application/x-123                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 52
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         19
# application/x-bittorrent             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  4
# application/x-dosexec                Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               5685
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       2643
# application/x-dosexec,binary         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         24
# application/x-dosexec,text/plain     Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          1
# application/x-elc                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                496
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         72
# application/x-font-ttf               Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         16
# application/x-gzip                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 14
# application/x-shockwave-flash        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               7328
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       2482
# application/x-shockwave-flash,binary Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
# ...                                                                                                         ...
# image/png                            Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      19078
# image/svg+xml                        Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         47
# image/tiff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  7
# image/x-icon                         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 62
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        432
# image/x-ms-bmp                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 90
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         45
# text/html                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              94276
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      46765
# text/plain                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              89484
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      56085
# text/plain,text/plain                Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          4
# text/troff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                185
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         49
# text/x-asm                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                946
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        239
# text/x-c                             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                998
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        296
# text/x-c++                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 24
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          4
# text/x-pascal                        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 23
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          9
# text/x-php                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  7
# video/mp2p                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
# video/mp4                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 45
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         34
# video/x-flv                          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                170
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        116
# video/x-ms-asf                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  1
# video/x-msvideo                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  2
#
#                                                                                                       trans_depth  \
# resp_mime_types                      user_agent
# -                                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                64458
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        45411
# application/msword                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                    1
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)            1
# application/octet-stream             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  775
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          875
# application/pdf                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 2768
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          143
# application/vnd.ms-cab-compressed    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           12
# application/vnd.ms-fontobject        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 1008
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         1151
# application/vnd.ms-opentype          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   25
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           23
# application/x-123                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   52
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           19
# application/x-bittorrent             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                    4
# application/x-dosexec                Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 5685
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         2643
# application/x-dosexec,binary         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                    2
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           24
# application/x-dosexec,text/plain     Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)            1
# application/x-elc                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  496
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           72
# application/x-font-ttf               Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           16
# application/x-gzip                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   14
# application/x-shockwave-flash        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 7328
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         2482
# application/x-shockwave-flash,binary Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                    2
# ...                                                                                                           ...
# image/png                            Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        19078
# image/svg+xml                        Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           47
# image/tiff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                    7
# image/x-icon                         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   62
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          432
# image/x-ms-bmp                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   90
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           45
# text/html                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                94276
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        46765
# text/plain                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                89484
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        56085
# text/plain,text/plain                Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)            4
# text/troff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  185
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           49
# text/x-asm                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  946
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          239
# text/x-c                             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  998
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          296
# text/x-c++                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   24
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)            4
# text/x-pascal                        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   23
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)            9
# text/x-php                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                    7
# video/mp2p                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                    2
# video/mp4                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   45
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           34
# video/x-flv                          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  170
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          116
# video/x-ms-asf                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                    1
# video/x-msvideo                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                    2
#
#                                                                                                       method  \
# resp_mime_types                      user_agent
# -                                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)           64458
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)   45411
# application/msword                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               1
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       1
# application/octet-stream             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)             775
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)     875
# application/pdf                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)            2768
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)     143
# application/vnd.ms-cab-compressed    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      12
# application/vnd.ms-fontobject        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)            1008
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)    1151
# application/vnd.ms-opentype          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              25
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      23
# application/x-123                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              52
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      19
# application/x-bittorrent             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               4
# application/x-dosexec                Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)            5685
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)    2643
# application/x-dosexec,binary         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               2
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      24
# application/x-dosexec,text/plain     Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       1
# application/x-elc                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)             496
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      72
# application/x-font-ttf               Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      16
# application/x-gzip                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              14
# application/x-shockwave-flash        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)            7328
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)    2482
# application/x-shockwave-flash,binary Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               2
# ...                                                                                                      ...
# image/png                            Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)   19078
# image/svg+xml                        Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      47
# image/tiff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               7
# image/x-icon                         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              62
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)     432
# image/x-ms-bmp                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)              90
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)      45
# text/html                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)           94276
# ...
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)              296
# text/x-c++                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                       24
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                4
# text/x-pascal                        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                       23
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)                9
# text/x-php                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                        7
# video/mp2p                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                        2
# video/mp4                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                       45
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)               34
# video/x-flv                          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                      170
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)              116
# video/x-ms-asf                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                        1
# video/x-msvideo                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                        2
#
#                                                                                                       resp_fuids  \
# resp_mime_types                      user_agent
# -                                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               64458
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       45411
# application/msword                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   1
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           1
# application/octet-stream             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 775
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         875
# application/pdf                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                2768
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         143
# application/vnd.ms-cab-compressed    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          12
# application/vnd.ms-fontobject        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                1008
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        1151
# application/vnd.ms-opentype          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  25
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          23
# application/x-123                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  52
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          19
# application/x-bittorrent             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   4
# application/x-dosexec                Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                5685
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        2643
# application/x-dosexec,binary         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   2
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          24
# application/x-dosexec,text/plain     Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           1
# application/x-elc                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 496
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          72
# application/x-font-ttf               Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  29
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          16
# application/x-gzip                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  14
# application/x-shockwave-flash        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                7328
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)        2482
# application/x-shockwave-flash,binary Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   2
# ...                                                                                                          ...
# image/png                            Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       19078
# image/svg+xml                        Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          47
# image/tiff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   7
# image/x-icon                         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  62
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         432
# image/x-ms-bmp                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  90
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          45
# text/html                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               94276
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       46765
# text/plain                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               89484
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       56085
# text/plain,text/plain                Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           4
# text/troff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 185
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          49
# text/x-asm                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 946
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         239
# text/x-c                             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 998
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         296
# text/x-c++                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  24
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           4
# text/x-pascal                        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  23
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)           9
# text/x-php                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   7
# video/mp2p                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   2
# video/mp4                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                  45
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)          34
# video/x-flv                          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                 170
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)         116
# video/x-ms-asf                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   1
# video/x-msvideo                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)                   2
#
#                                                                                                       sample
# resp_mime_types                      user_agent
# -                                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/msword                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/octet-stream             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/pdf                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/vnd.ms-cab-compressed    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/vnd.ms-fontobject        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/vnd.ms-opentype          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/x-123                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/x-bittorrent             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
# application/x-dosexec                Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/x-dosexec,binary         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/x-dosexec,text/plain     Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/x-elc                    Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/x-font-ttf               Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/x-gzip                   Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
# application/x-shockwave-flash        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# application/x-shockwave-flash,binary Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
# ...                                                                                                      ...
# image/png                            Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# image/svg+xml                        Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# image/tiff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
# image/x-icon                         Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# image/x-ms-bmp                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# text/html                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# text/plain                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# text/plain,text/plain                Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# text/troff                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# text/x-asm                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# text/x-c                             Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# text/x-c++                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# text/x-pascal                        Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# text/x-php                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
# video/mp2p                           Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
# video/mp4                            Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# video/x-flv                          Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#                                      Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 5.1; Trident/4.0)       0
# video/x-ms-asf                       Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
# video/x-msvideo                      Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1)               0
#
# [80 rows x 25 columns]

# %% [markdown]
# Use the pre-defined filetypes below to come up with a couple of interesting views on the data that involve the **groupby()** function.

# %%
executable_types = set(['application/x-dosexec', 'application/octet-stream', 'binary', 'application/vnd.ms-cab-compressed'])
common_exploit_types = set(['application/x-java-applet','application/pdf','application/zip','application/jar','application/x-shockwave-flash'])

# %% [markdown]
# ### Graphing Groupby Data
# One advantage of the **groupby()** command is being able to graph the output to get another view into the data. One popular way to do this is via a bar graph.
#
# In the next cell there are a couple of things going on. First, a column named *count* is created and every row in that column is assigned the value of 1. This creates a column that we can use pandas to sum on since it has a value of 1 for each row.
#
# In the second line, the dataframe is grouped by *resp_mime_types* and then only the *count* column is viewed/returned from the **groupby()** command. The result is then passed to the **sum()** function, this causes the sum on the *count* column, which due to the trick above has a value of 1 for each row. Combined this gets the number of files in each filetype. The result is simply plotted with **plot()**.
#
# Any surprising results? What could they possibly indicate?

# %%
http_df['count'] = 1
http_df.groupby('resp_mime_types')['count'].sum().plot(kind='bar')

# %% [markdown]
# The technique above can be used to look at the number of samples associated with each IP in dataset.
#
# What kinds of conclusions can you draw based on the graph below?

# %%
http_df.groupby('id.orig_h')['count'].sum().order(ascending=False).plot(kind='bar')

# %% [markdown]
# That's a lot of IP addresses! Bonus question: How many different source IP addresses are in the data set?
#
# Remember above when we said you could access elements in a dataframe that weren't indexed by a timestamp like a regular Python array? Well, it's possible to do the same with dataframes produced by **groupby()**. By sliding around the dataset below what can you learn about the IP addresses that wasn't possible to see because of the resolution of the graph above?

# %%
http_df.groupby('id.orig_h')['count'].sum().order(ascending=False)[:10].plot(kind='bar')

# %% [markdown]
# ### Stacked Groupby Graphs With Bonus Colors
# Once you learn the basic bar graph, it's time to kick it up a notch by looking at the relationship between two different columns. This can be done with stacked bar charts.
#
# In this case the relationship between filetype and HTTP method can be explored. Perhaps one or two HTTP methods are more responsible for specific filetypes vs. others. Custom colors can be created with the values in the **colors** list, and passed into the graph with **color=colors**. Similar to the examples above we're using our added *count* column to get the number of things. In this example multiple tiers are used for **groupby()** since the breakdown of methods by filetype are being explored. The **unstack()** function "expands" the grouped columns, and **fillna(0)** fills all non-values with zero (since these won't impact the sum).
#
# What happens when you remove the custom color labels?
#
# Bonus: Create a new cell and take a look at what the dataframe looks like without the **plot()** or other commands stacked on top of one another. This is useful to do to understand the output of each function in the chain.

# %%
colors = [(x/10.0, x/40.0, 0.75) for x in range(len(http_df['method'].unique().tolist()))]
http_df.groupby(['resp_mime_types','method'])['count'].sum().unstack('method').fillna(0).plot(
    color=colors, kind='bar', stacked=True, grid=False)

# %% [markdown]
# ## Final Exercise
# The final challenge is using all the techniques from above to create a stacked bar chart that shows: only for destination ports 81, 88, and 8080 how many of each HTTP method is associated with each port. The **plot()** command is present to show another way to specifiy different custom colors.

# %%
http_df[http_df['id.resp_p'].isin([8080,81,88])].groupby(['id.resp_p','method'])['count'].sum().unstack('method').fillna(0).plot(
    colormap='GnBu', kind='bar', stacked=True, grid=False)
